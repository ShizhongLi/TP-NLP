# %%
import tensorflow as tf
import keras
import gensim
import numpy as np
import pandas as pd
import logging  
import time  
import os  
import jieba  
import glob  
import random  
import copy  
import chardet  
from gensim import corpora,similarities, models  
from pprint import pprint  
import jieba.analyse
import jieba.posseg as pseg
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer  
from sklearn.decomposition import PCA  
import sklearn
# Out:
# Using TensorFlow backend.
# D:\program\Anaconda\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
df_doctor_order = pd.read_csv('4_outpatient_doctor_order_detail.csv')
df_doctor_order.head()
# Out:
#   HOSPITAL_CODE      SERIAL_NO   ITEM_NO ITEM_CODE              ITEM_NAME  \
# 0   43120181600  1367431129172  68751496     23357  （急）B型钠尿肽前体（PRO-BNP）测定
# 1   43120181600  1367431129172  68751497     23496          （急）降钙素原检测（定量）
# 2   43120181600   558100129171  61151855     20431    （急）血清肌酸激酶－MB同工酶质量测定
# 3   43120181600   558100129171  61151853     20436              （急）血清尿酸测定
# 4   43120181600   558100129171  61151850     23261       （急）血清总蛋白测定（化学法等）
#
#    BASE_DOSE DOSE_UNIT SPECS  DOSE_ONCE  TOTAL    ...     DRUG_IND  COSTS  \
# 0        NaN       NaN     1        NaN    1.0    ...            0  220.0
# 1        NaN       NaN     1        NaN    1.0    ...            0  150.0
# 2        NaN       NaN     1        NaN    1.0    ...            0   50.0
# 3        NaN       NaN     1        NaN    1.0    ...            0    8.0
# 4        NaN       NaN     1        NaN    1.0    ...            0    5.0
#
#   EXEC_CODE EXEC_DPNM                    UPDATED_ON  SYS_ITEM_NAME  \
# ...

# %%
df_doctor_order.shape
# Out:
# (5644, 24)

# %%
df_doctor_order.dtypes
# Out:
# HOSPITAL_CODE      object
# SERIAL_NO           int64
# ITEM_NO             int64
# ITEM_CODE          object
# ITEM_NAME          object
# BASE_DOSE         float64
# DOSE_UNIT          object
# SPECS              object
# DOSE_ONCE         float64
# TOTAL             float64
# UNIT               object
# FREQ_CODE          object
# FREQUENCY_NAME     object
# USE_NAME           object
# DRUG_IND            int64
# COSTS             float64
# EXEC_CODE         float64
# EXEC_DPNM          object
# UPDATED_ON         object
# SYS_ITEM_NAME      object
# SYS_DOSE_UNIT      object
# SYS_UNIT           object
# SYS_USE_NAME       object
# ITEM_CLASS         object
# dtype: object

# %%
df_doctor_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Data columns (total 24 columns):
# HOSPITAL_CODE     5644 non-null object
# SERIAL_NO         5644 non-null int64
# ITEM_NO           5644 non-null int64
# ITEM_CODE         5644 non-null object
# ITEM_NAME         5644 non-null object
# BASE_DOSE         241 non-null float64
# DOSE_UNIT         2001 non-null object
# SPECS             5608 non-null object
# DOSE_ONCE         2011 non-null float64
# TOTAL             5644 non-null float64
# UNIT              5644 non-null object
# FREQ_CODE         2008 non-null object
# FREQUENCY_NAME    2007 non-null object
# USE_NAME          2001 non-null object
# DRUG_IND          5644 non-null int64
# COSTS             5644 non-null float64
# EXEC_CODE         4650 non-null float64
# EXEC_DPNM         4650 non-null object
# UPDATED_ON        5644 non-null object
# SYS_ITEM_NAME     6 non-null object
# SYS_DOSE_UNIT     161 non-null object
# ...

# %%
df_doctor_order.describe()
# Out:
#           SERIAL_NO       ITEM_NO   BASE_DOSE    DOSE_ONCE        TOTAL  \
# count  5.644000e+03  5.644000e+03  241.000000  2011.000000  5644.000000
# mean   6.758626e+11  3.765536e+07   20.361286    78.988456     3.732636
# std    7.877234e+11  3.231003e+07   55.499145   199.411771    18.298505
# min    3.782790e+05  1.000000e+00    0.000000     0.000000     1.000000
# 25%    1.712015e+10  2.000335e+06    1.000000     3.500000     1.000000
# 50%    5.183511e+11  6.084686e+07    1.000000    30.000000     1.000000
# 75%    1.329844e+12  6.841651e+07    8.000000   100.000000     1.000000
# max    1.735939e+13  7.442625e+07  400.000000  4250.000000   420.000000
#
#           DRUG_IND        COSTS    EXEC_CODE
# count  5644.000000  5644.000000  4650.000000
# mean      0.354536    39.742332   334.604946
# std       0.478415   114.726997   123.161066
# min       0.000000     0.108000   102.000000
# 25%       0.000000     4.000000   201.000000
# 50%       0.000000     8.000000   413.000000
# ...

# %%
for i, v in enumerate(df_doctor_order.columns):
    print(i, v)
# Out:
# 0 HOSPITAL_CODE
# 1 SERIAL_NO
# 2 ITEM_NO
# 3 ITEM_CODE
# 4 ITEM_NAME
# 5 BASE_DOSE
# 6 DOSE_UNIT
# 7 SPECS
# 8 DOSE_ONCE
# 9 TOTAL
# 10 UNIT
# 11 FREQ_CODE
# 12 FREQUENCY_NAME
# 13 USE_NAME
# 14 DRUG_IND
# 15 COSTS
# 16 EXEC_CODE
# 17 EXEC_DPNM
# 18 UPDATED_ON
# 19 SYS_ITEM_NAME
# 20 SYS_DOSE_UNIT
# 21 SYS_UNIT
# 22 SYS_USE_NAME
# 23 ITEM_CLASS

# %%
sum(df_doctor_order.duplicated())
# Out:
# 0

# %%
df_exam_info = pd.read_csv('9_outpatient_exam_info.csv')
df_exam_info.head()
# Out:
#    HOSPITAL_CODE  CHECKSERIALNUM  INPATIENT_NO       PATIENT_ID  CLINIC_ID  \
# 0    43120181600  20170610000407           NaN       1000073494  2857340.0
# 1    43120181600  20170612002668           NaN  5300-0000092951  3804144.0
# 2    43120181600  20170707001233           NaN       1000157523  3385061.0
# 3    43120181600  20170707001397           NaN       1000157523  3385061.0
# 4    43120181600  20170710002117         587.0       0101035250        NaN
#
#    PATIENT_NO PATIENTNAME            PROVINCE SEX  AGE   ...    \
# 0         NaN          杨*  530102********271X   男   68   ...
# 1         NaN         章*仁  530102********2112   男   75   ...
# 2         NaN         余*亚  520202********0017   男   71   ...
# 3         NaN         余*亚  520202********0017   男   71   ...
# 4   8000418.0          高*  530102********2431   男   38   ...
#
#   OUTP_PATIENT_NO EXAM_EMP_NO EXAM_DOCTOR  SEQ_ID OPEN_SYS_EMP_NO  \
# 0        905405.0         NaN         NaN    1335             NaN
# ...

# %%
df_exam_info.shape
# Out:
# (1795, 46)

# %%
df_exam_info.dtypes
# Out:
# HOSPITAL_CODE        int64
# CHECKSERIALNUM       int64
# INPATIENT_NO       float64
# PATIENT_ID          object
# CLINIC_ID          float64
# PATIENT_NO         float64
# PATIENTNAME         object
# PROVINCE            object
# SEX                 object
# AGE                  int64
# PATIENT_TYPE        object
# BIRTHDAY            object
# PHONENUMBER         object
# DEVICETYPECODE       int64
# DEVICETYPENAME      object
# APPLY_NO            object
# IMAGEID             object
# ITEM_SNOMED        float64
# ITEM_CODE           object
# ITEMNAME            object
# CHECKMETHOD         object
# PICTURENUM           int64
# EMERGENCY_TREAT    float64
# IFMASCULINE          int64
# EXEC_DPNMID        float64
# EXEC_DPNM           object
# OPEN_EMP_NO        float64
# OPEN_DOCTOR         object
# STUDYTIME          float64
# STUDYSTATUSNAME     object
# REPORTDESCRIBE      object
# REPORTDIAGNOSE      object
# REP_EMP_NO         float64
# DOCNAME             object
# ...

# %%
df_exam_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 46 columns):
# HOSPITAL_CODE      1795 non-null int64
# CHECKSERIALNUM     1795 non-null int64
# INPATIENT_NO       1587 non-null float64
# PATIENT_ID         1795 non-null object
# CLINIC_ID          208 non-null float64
# PATIENT_NO         1587 non-null float64
# PATIENTNAME        1795 non-null object
# PROVINCE           1795 non-null object
# SEX                1795 non-null object
# AGE                1795 non-null int64
# PATIENT_TYPE       1795 non-null object
# BIRTHDAY           1795 non-null object
# PHONENUMBER        1795 non-null object
# DEVICETYPECODE     1795 non-null int64
# DEVICETYPENAME     1795 non-null object
# APPLY_NO           1791 non-null object
# IMAGEID            1795 non-null object
# ITEM_SNOMED        0 non-null float64
# ITEM_CODE          1795 non-null object
# ITEMNAME           1795 non-null object
# CHECKMETHOD        1795 non-null object
# ...

# %%
for i, v in enumerate(df_exam_info.columns):
    print(i, v)
# Out:
# 0 HOSPITAL_CODE
# 1 CHECKSERIALNUM
# 2 INPATIENT_NO
# 3 PATIENT_ID
# 4 CLINIC_ID
# 5 PATIENT_NO
# 6 PATIENTNAME
# 7 PROVINCE
# 8 SEX
# 9 AGE
# 10 PATIENT_TYPE
# 11 BIRTHDAY
# 12 PHONENUMBER
# 13 DEVICETYPECODE
# 14 DEVICETYPENAME
# 15 APPLY_NO
# 16 IMAGEID
# 17 ITEM_SNOMED
# 18 ITEM_CODE
# 19 ITEMNAME
# 20 CHECKMETHOD
# 21 PICTURENUM
# 22 EMERGENCY_TREAT
# 23 IFMASCULINE
# 24 EXEC_DPNMID
# 25 EXEC_DPNM
# 26 OPEN_EMP_NO
# 27 OPEN_DOCTOR
# 28 STUDYTIME
# 29 STUDYSTATUSNAME
# 30 REPORTDESCRIBE
# 31 REPORTDIAGNOSE
# 32 REP_EMP_NO
# 33 DOCNAME
# 34 OPERATETIME
# 35 UPDATED_ON
# 36 OUTP_PATIENT_NO
# 37 EXAM_EMP_NO
# 38 EXAM_DOCTOR
# 39 SEQ_ID
# 40 OPEN_SYS_EMP_NO
# 41 DATA_VERSION
# 42 SYS_CHECKMETHOD
# 43 SYS_ITEMNAME
# 44 SYS_CHECKNAME
# 45 PATI_ID

# %%
sum(df_exam_info.duplicated())
# Out:
# 0

# %%
df_main_doctorOrder = pd.read_csv('3_outpatient_doctor_order_main_record.csv')
df_main_doctorOrder.head()
# Out:
#   HOSPITAL_CODE      SERIAL_NO VISIT_DATE  OUTP_PATIENT_NO  DEPT_CODE  \
# 0   43120181600  1216818129171  2018/1/16          1216818       18.0
# 1   43120181600  1216818129221  2018/1/16          1216818       18.0
# 2   43120181600  1216818129281  2018/1/16          1216818       18.0
# 3   43120181600    18011654389  2018/1/16          1216818       18.0
# 4   43120181600  1438773129172   2018/3/1          1438773       18.0
#
#   ORDERED_BY  EMP_NO DOCTOR ORDERED_DATE                    UPDATED_ON  \
# 0       急诊内科   30380    杨爱华    2018/1/16  31-7月 -18 04.13.08.000000 下午
# 1       急诊内科   30380    杨爱华    2018/1/16  31-7月 -18 04.13.08.000000 下午
# 2       急诊内科   30380    杨爱华    2018/1/16  31-7月 -18 04.13.08.000000 下午
# 3       急诊内科   30380    杨爱华    2018/1/16  31-7月 -18 04.13.08.000000 下午
# 4       急诊内科   30391    曹云友     2018/3/1  31-7月 -18 04.13.08.000000 下午
#
#     SEQ_ID  OPEN_SYS_EMP_NO  DATA_VERSION
# 0  2312287              NaN             0
# ...

# %%
df_main_doctorOrder.shape
# Out:
# (1204, 13)

# %%
df_main_doctorOrder.dtypes
# Out:
# HOSPITAL_CODE       object
# SERIAL_NO            int64
# VISIT_DATE          object
# OUTP_PATIENT_NO      int64
# DEPT_CODE          float64
# ORDERED_BY          object
# EMP_NO               int64
# DOCTOR              object
# ORDERED_DATE        object
# UPDATED_ON          object
# SEQ_ID               int64
# OPEN_SYS_EMP_NO    float64
# DATA_VERSION         int64
# dtype: object

# %%
df_main_doctorOrder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 13 columns):
# HOSPITAL_CODE      1204 non-null object
# SERIAL_NO          1204 non-null int64
# VISIT_DATE         1204 non-null object
# OUTP_PATIENT_NO    1204 non-null int64
# DEPT_CODE          1202 non-null float64
# ORDERED_BY         1204 non-null object
# EMP_NO             1204 non-null int64
# DOCTOR             1204 non-null object
# ORDERED_DATE       1204 non-null object
# UPDATED_ON         1204 non-null object
# SEQ_ID             1204 non-null int64
# OPEN_SYS_EMP_NO    0 non-null float64
# DATA_VERSION       1204 non-null int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 122.4+ KB

# %%
for i, v in enumerate(df_main_doctorOrder.columns):
    print(i, v)
# Out:
# 0 HOSPITAL_CODE
# 1 SERIAL_NO
# 2 VISIT_DATE
# 3 OUTP_PATIENT_NO
# 4 DEPT_CODE
# 5 ORDERED_BY
# 6 EMP_NO
# 7 DOCTOR
# 8 ORDERED_DATE
# 9 UPDATED_ON
# 10 SEQ_ID
# 11 OPEN_SYS_EMP_NO
# 12 DATA_VERSION

# %%
sum(df_main_doctorOrder.duplicated())
# Out:
# 0

# %% [markdown]
# # 2.下面从各数据表中提取深度学习训练用到的关键数据，并通过外键进行join连接

# %%
df_exam_exact = df_exam_info.loc[:, ['OUTP_PATIENT_NO','REPORTDESCRIBE','REPORTDIAGNOSE']]
df_exam_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         905405.0  2017年6月10日16:21:08\n\n急诊报告：\n\n1.慢性支气管炎CT征象。\n...
# 1        1200132.0  CDFI及CDE彩色多普勒超声宽景成像显示：\n双侧下肢（股总、股浅、股深近心段、腘、胫后、...
# 2        1069537.0  2017年7月7日10:20:19\n\n    腰椎生理曲度变直，序列整齐，椎体边缘变尖，...
# 3        1069537.0            \n    腰椎生理曲度变直，各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体...
# 4              NaN                                                NaN
#
#                                       REPORTDIAGNOSE
# 0  1.慢性支气管炎CT征象。\n2.双肺见小结节、条索影，多考虑为慢性感染性病变，建议治疗后复...
# 1  1.左侧下肢股总静脉瓣膜功能不全（轻度）。\n2.左侧下肢小腿段浅静脉曲张。\n3.双侧下肢...
# 2                         1、腰椎退行性改变。\n2、腰5-骶1关节间隙变窄。
# 3     各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体明显，腰5椎体下缘及骶1椎体上缘异常信号影，...
# 4                                                NaN

# %%
df_exam_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 3 columns):
# OUTP_PATIENT_NO    208 non-null float64
# REPORTDESCRIBE     1615 non-null object
# REPORTDIAGNOSE     1611 non-null object
# dtypes: float64(1), object(2)
# memory usage: 42.1+ KB

# %%
for i in range(len(df_exam_exact)):
  if np.isnan(df_exam_exact['OUTP_PATIENT_NO'][i]) or pd.isnull(df_exam_exact['REPORTDIAGNOSE'][i]):
    df_exam_exact = df_exam_exact.drop(i)

df_exam_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 1773
# Data columns (total 3 columns):
# OUTP_PATIENT_NO    199 non-null float64
# REPORTDESCRIBE     199 non-null object
# REPORTDIAGNOSE     199 non-null object
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
df_exam_exact['describe_wordlist'] = df_exam_exact['REPORTDESCRIBE'].map(lambda x: list(jieba.cut(x)))
# df_exam_exact['wordlist'] = df_exam_exact['REPORTDESCRIBE'].map(lambda x: list(x))

df_exam_exact.head()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Acer\AppData\Local\Temp\jieba.cache
# Loading model cost 0.951 seconds.
# Prefix dict has been built succesfully.
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         905405.0  2017年6月10日16:21:08\n\n急诊报告：\n\n1.慢性支气管炎CT征象。\n...
# 1        1200132.0  CDFI及CDE彩色多普勒超声宽景成像显示：\n双侧下肢（股总、股浅、股深近心段、腘、胫后、...
# 2        1069537.0  2017年7月7日10:20:19\n\n    腰椎生理曲度变直，序列整齐，椎体边缘变尖，...
# 3        1069537.0            \n    腰椎生理曲度变直，各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体...
# 8         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1.慢性支气管炎CT征象。\n2.双肺见小结节、条索影，多考虑为慢性感染性病变，建议治疗后复...
# 1  1.左侧下肢股总静脉瓣膜功能不全（轻度）。\n2.左侧下肢小腿段浅静脉曲张。\n3.双侧下肢...
# 2                         1、腰椎退行性改变。\n2、腰5-骶1关节间隙变窄。
# 3     各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体明显，腰5椎体下缘及骶1椎体上缘异常信号影，...
# 8  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
# ...

# %%
df_exam_exact['describe_keywords'] = df_exam_exact['REPORTDESCRIBE'].map(lambda x:jieba.analyse.extract_tags(x,10))
df_exam_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         905405.0  2017年6月10日16:21:08\n\n急诊报告：\n\n1.慢性支气管炎CT征象。\n...
# 1        1200132.0  CDFI及CDE彩色多普勒超声宽景成像显示：\n双侧下肢（股总、股浅、股深近心段、腘、胫后、...
# 2        1069537.0  2017年7月7日10:20:19\n\n    腰椎生理曲度变直，序列整齐，椎体边缘变尖，...
# 3        1069537.0            \n    腰椎生理曲度变直，各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体...
# 8         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1.慢性支气管炎CT征象。\n2.双肺见小结节、条索影，多考虑为慢性感染性病变，建议治疗后复...
# 1  1.左侧下肢股总静脉瓣膜功能不全（轻度）。\n2.左侧下肢小腿段浅静脉曲张。\n3.双侧下肢...
# 2                         1、腰椎退行性改变。\n2、腰5-骶1关节间隙变窄。
# 3     各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体明显，腰5椎体下缘及骶1椎体上缘异常信号影，...
# 8  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [2017, 年, 6, 月, 10, 日, 16, :, 21, :, 08, \n, \...
# 1  [CDFI, 及, CDE, 彩色, 多普勒, 超声, 宽景, 成像, 显示, ：, \n,...
# 2  [2017, 年, 7, 月, 7, 日, 10, :, 20, :, 19, \n, \n...
# ...

# %%
df_exam_exact.reset_index(drop=True)
# Out:
#      OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0           905405.0  2017年6月10日16:21:08\n\n急诊报告：\n\n1.慢性支气管炎CT征象。\n...
# 1          1200132.0  CDFI及CDE彩色多普勒超声宽景成像显示：\n双侧下肢（股总、股浅、股深近心段、腘、胫后、...
# 2          1069537.0  2017年7月7日10:20:19\n\n    腰椎生理曲度变直，序列整齐，椎体边缘变尖，...
# 3          1069537.0            \n    腰椎生理曲度变直，各腰椎椎体骨质前后缘增生变尖，尤以腰5椎体...
# 4           483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 5           409793.0  急诊报告\n2017年8月17日16:20:38\n1、左侧少量气胸，左肺组织被压缩约5%。...
# 6           757686.0  2017年8月18日09:35:57\n\n    定位像示颈椎生理曲度存在，各椎间隙无变窄...
# 7           409853.0  2017年8月17日22:26:27\n急诊报告；\n1.慢性支气管炎、肺气肿、肺心病CT征...
# 8           430115.0  2017年8月23日9:01:59\n    胸廓对称，纵隔气管未见移位。双肺支气管血管束增...
# 9           442894.0  2017年8月24日8:51:58\n    胸廓对称，纵隔气管未见移位。双肺纹理增多、增粗...
# 10          476442.0  2017年8月29日23:06:27\n急诊报告：\n1、慢性支气管炎、肺气肿征象。\n2、...
# 11          483833.0  2017年8月30日9:13:33\n影像所见\n\n1、慢性支气管炎、肺气肿CT征象，双肺...
# ...

# %% [markdown]
# # 2.2 接下来提取医嘱主记录表和医嘱明细表的关键数据

# %%
df_main_doctorOrder_exact = df_main_doctorOrder[['SERIAL_NO','OUTP_PATIENT_NO']]
df_main_doctorOrder_exact.head()
# Out:
#        SERIAL_NO  OUTP_PATIENT_NO
# 0  1216818129171          1216818
# 1  1216818129221          1216818
# 2  1216818129281          1216818
# 3    18011654389          1216818
# 4  1438773129172          1438773

# %%
df_main_doctorOrder_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 2 columns):
# SERIAL_NO          1204 non-null int64
# OUTP_PATIENT_NO    1204 non-null int64
# dtypes: int64(2)
# memory usage: 18.9 KB

# %%
df_doctorOrder_detail_exact = df_doctor_order[['SERIAL_NO','ITEM_CODE','ITEM_NAME']]
df_doctorOrder_detail_exact.head()
# Out:
#        SERIAL_NO ITEM_CODE              ITEM_NAME
# 0  1367431129172     23357  （急）B型钠尿肽前体（PRO-BNP）测定
# 1  1367431129172     23496          （急）降钙素原检测（定量）
# 2   558100129171     20431    （急）血清肌酸激酶－MB同工酶质量测定
# 3   558100129171     20436              （急）血清尿酸测定
# 4   558100129171     23261       （急）血清总蛋白测定（化学法等）

# %%
df_doctorOrder_detail_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5644 entries, 0 to 5643
# Data columns (total 3 columns):
# SERIAL_NO    5644 non-null int64
# ITEM_CODE    5644 non-null object
# ITEM_NAME    5644 non-null object
# dtypes: int64(1), object(2)
# memory usage: 132.4+ KB

# %% [markdown]
# # 2.4 接下来进行聚合操作

# %%
df_join_exam_and_mainDoctorOrder_exact = pd.merge(df_exam_exact, df_main_doctorOrder_exact, how='inner', on=['OUTP_PATIENT_NO'])
df_join_exam_and_mainDoctorOrder_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 1         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 2         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 3         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 4         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 1  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 2  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 3  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 4  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 1  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 2  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# ...

# %%
df_join_exam_and_mainDoctorOrder_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 717 entries, 0 to 716
# Data columns (total 6 columns):
# OUTP_PATIENT_NO      717 non-null float64
# REPORTDESCRIBE       717 non-null object
# REPORTDIAGNOSE       717 non-null object
# describe_wordlist    717 non-null object
# describe_keywords    717 non-null object
# SERIAL_NO            717 non-null int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 39.2+ KB

# %%
df_join_exam_and_doctorOrderDetail_exact = pd.merge(df_join_exam_and_mainDoctorOrder_exact, df_doctorOrder_detail_exact, how='inner', on=['SERIAL_NO'])
df_join_exam_and_doctorOrderDetail_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 1         483018.0  2017年8月30日20:06:15\n急诊报告：\n1、慢性支气管炎、肺气肿征象。\n2、...
# 2         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 3         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 4         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 1  1、慢性支气管炎、肺气肿征象。\n2、左肺上叶尖后段局部支气管扩张。\n3、双肺上叶尖（后）...
# 2  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 3  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 4  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 1  [2017, 年, 8, 月, 30, 日, 20, :, 06, :, 15, \n, 急...
# 2  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# ...

# %%
df_join_exam_and_doctorOrderDetail_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3601 entries, 0 to 3600
# Data columns (total 8 columns):
# OUTP_PATIENT_NO      3601 non-null float64
# REPORTDESCRIBE       3601 non-null object
# REPORTDIAGNOSE       3601 non-null object
# describe_wordlist    3601 non-null object
# describe_keywords    3601 non-null object
# SERIAL_NO            3601 non-null int64
# ITEM_CODE            3601 non-null object
# ITEM_NAME            3601 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 253.2+ KB

# %% [markdown]
# # 3. 接下来进行对诊断信息分词进行word embedding

# %%
describe_words_lists = df_join_exam_and_doctorOrderDetail_exact['describe_wordlist'].values
describe_all_words = np.hstack(describe_words_lists)
describe_word_bag = set(describe_all_words)
describe_word_bag
# Out:
# {'特异性',
#  '09',
#  '征',
#  '日本',
#  '分界',
#  '完整',
#  '骨瘤',
#  '少量',
#  '前移',
#  '变影',
#  '变尖',
#  '下野',
#  '12mm',
#  '宽景',
#  '感染',
#  '年',
#  ':',
#  '病人',
#  '包裹',
#  '未见',
#  '所示',
#  '确切',
#  '皮层',
#  '枕部',
#  '肠壁',
#  '关节',
#  '空洞',
#  '系统',
#  '肺散',
#  '一团',
#  '蝶骨',
#  '55',
#  '24',
#  '尚',
#  '陈旧性',
#  '及主',
#  '面光',
#  '慢性感染',
#  '胃肠',
#  '狭窄',
#  '下',
#  '简直',
#  '其它',
#  '见小斑',
#  '肾囊肿',
#  '右侧',
#  '稍长',
#  '气管炎',
#  '外形',
#  '被',
#  '强',
#  '偏曲',
#  '空肠',
#  '复查',
#  '腔隙性',
#  '区',
#  '长',
#  '肺动脉',
#  '集合',
#  '区域',
#  '5.0',
#  'T1',
#  '2017',
#  '左支',
#  '蝶窦',
#  '及桥',
#  '及叶间',
#  '膝降',
#  '3.2',
#  '邻近',
#  '07',
#  '排外',
#  '有无',
#  '进一步',
#  '腹股沟',
#  '肺门影',
#  '血管',
#  '实变',
#  '主干',
#  '\n',
#  '体未见',
#  '管影',
#  '以上',
#  '可',
#  '玻璃',
#  '整',
#  '斜径',
#  '0.50',
#  '胃腔',
#  '肌及',
#  '外侧',
#  '42',
#  '损害',
#  '对比',
#  '底部',
#  '置入',
#  '管状',
#  '结核',
#  '精囊',
#  '两侧',
#  '腘',
#  '多',
#  '叶',
#  '反射',
#  'CTA',
#  '及磨',
#  '骨折',
#  '引出',
#  '内侧',
#  '亦',
# ...

# %%
len(describe_word_bag)
# Out:
# 1137

# %%
from collections import Counter
describe_counts = Counter(describe_word_bag)
describe_vocab = sorted(describe_counts, key=describe_counts.get, reverse=True)
describe_vocab_to_int = {word:ii for ii, word in enumerate(describe_vocab, 1)}

describe_ints = []
for each in describe_words_lists:
    describe_ints.append([describe_vocab_to_int[word] for word in each])

# %%
describe_vocab_to_int
# Out:
# {'特异性': 1,
#  '09': 2,
#  '征': 3,
#  '日本': 4,
#  '分界': 5,
#  '完整': 6,
#  '骨瘤': 7,
#  '少量': 8,
#  '前移': 9,
#  '变影': 10,
#  '变尖': 11,
#  '下野': 12,
#  '12mm': 13,
#  '宽景': 14,
#  '感染': 15,
#  '年': 16,
#  ':': 17,
#  '病人': 18,
#  '包裹': 19,
#  '未见': 20,
#  '所示': 21,
#  '确切': 22,
#  '皮层': 23,
#  '枕部': 24,
#  '肠壁': 25,
#  '关节': 26,
#  '空洞': 27,
#  '系统': 28,
#  '肺散': 29,
#  '一团': 30,
#  '蝶骨': 31,
#  '55': 32,
#  '24': 33,
#  '尚': 34,
#  '陈旧性': 35,
#  '及主': 36,
#  '面光': 37,
#  '慢性感染': 38,
#  '胃肠': 39,
#  '狭窄': 40,
#  '下': 41,
#  '简直': 42,
#  '其它': 43,
#  '见小斑': 44,
#  '肾囊肿': 45,
#  '右侧': 46,
#  '稍长': 47,
#  '气管炎': 48,
#  '外形': 49,
#  '被': 50,
#  '强': 51,
#  '偏曲': 52,
#  '空肠': 53,
#  '复查': 54,
#  '腔隙性': 55,
#  '区': 56,
#  '长': 57,
#  '肺动脉': 58,
#  '集合': 59,
#  '区域': 60,
#  '5.0': 61,
#  'T1': 62,
#  '2017': 63,
#  '左支': 64,
#  '蝶窦': 65,
#  '及桥': 66,
#  '及叶间': 67,
#  '膝降': 68,
#  '3.2': 69,
#  '邻近': 70,
#  '07': 71,
#  '排外': 72,
#  '有无': 73,
#  '进一步': 74,
#  '腹股沟': 75,
#  '肺门影': 76,
# ...

# %%
describe_ints
# Out:
# [[681,
#   566,
#   80,
#   63,
#   16,
#   746,
#   659,
#   769,
#   395,
#   769,
#   17,
#   211,
#   17,
#   623,
#   80,
#   361,
#   546,
#   580,
#   823,
#   56,
#   546,
#   882,
#   56,
#   968,
#   1014,
#   638,
#   905,
#   628,
#   128,
#   311,
#   254,
#   983,
#   80,
#   445,
#   546,
#   561,
#   665,
#   636,
#   983,
#   80,
#   130,
#   546,
#   1069,
#   871,
#   265,
#   123,
#   278,
#   284,
#   983],
#  [63,
#   16,
#   746,
#   659,
#   126,
#   395,
#   598,
#   17,
#   1036,
#   17,
#   769,
#   80,
#   681,
#   566,
#   788,
#   80,
#   361,
#   546,
#   396,
#   716,
#   546,
#   594,
#   329,
#   983,
#   80,
#   445,
#   546,
#   774,
#   555,
#   603,
#   197,
#   1066,
#   1011,
#   969,
#   748,
#   983,
#   80,
#   130,
#   546,
#   433,
#   555,
#   603,
#   839,
#   197,
#   1097,
#   1066,
#   245,
#   983,
#   80,
#   904,
#   546,
#   774,
#   555,
#   452,
#   378,
#   852,
#   461,
#   638,
#   905,
#   628,
#   872,
#   1093,
#   905,
# ...

# %%
describe_lens = Counter([len(describe) for describe in describe_ints])
max(describe_lens)
# Out:
# 391

# %%
seq_len = max(describe_lens) 
features = np.zeros((len(describe_ints), seq_len), dtype=int)
for ii, describe in enumerate(describe_ints):
    features[ii][-len(describe):] = np.array(describe)[:seq_len]
    
features[:10][:200]
# Out:
# array([[  0,   0,   0, ..., 278, 284, 983],
#        [  0,   0,   0, ..., 650, 329, 983],
#        [  0,   0,   0, ..., 278, 284, 983],
#        ...,
#        [  0,   0,   0, ..., 650, 329, 983],
#        [  0,   0,   0, ..., 650, 329, 983],
#        [  0,   0,   0, ..., 650, 329, 983]])

# %%
df_join_exam_and_doctorOrderDetail_exact['describe_ints'] = describe_ints
df_join_exam_and_doctorOrderDetail_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 1         483018.0  2017年8月30日20:06:15\n急诊报告：\n1、慢性支气管炎、肺气肿征象。\n2、...
# 2         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 3         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 4         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 1  1、慢性支气管炎、肺气肿征象。\n2、左肺上叶尖后段局部支气管扩张。\n3、双肺上叶尖（后）...
# 2  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 3  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 4  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 1  [2017, 年, 8, 月, 30, 日, 20, :, 06, :, 15, \n, 急...
# 2  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# ...

# %% [markdown]
# # 3.1.1 医嘱药品编码

# %%
doctor_orders = df_join_exam_and_doctorOrderDetail_exact['ITEM_CODE'].values
doctor_orders
# Out:
# array(['2434', '2434', '101032', ..., '23005', '23005', '23895'],
#       dtype=object)

# %%
doctor_orders_counter = Counter(doctor_orders)
doctor_orders_counter
# Out:
# Counter({'2434': 19,
#          '101032': 4,
#          '1623': 154,
#          '1645': 42,
#          '2405': 6,
#          '23895': 43,
#          '24130': 39,
#          '23005': 123,
#          '20436': 64,
#          '23261': 64,
#          '23264': 64,
#          '23282': 70,
#          '23286': 27,
#          '23294': 71,
#          '23296': 71,
#          '23298': 71,
#          '23300': 71,
#          '23302': 27,
#          '23304': 27,
#          '23310': 71,
#          '23314': 64,
#          '23316': 64,
#          '23318': 64,
#          '23324': 64,
#          '23326': 64,
#          '23361': 64,
#          '23364': 64,
#          '23253': 48,
#          '20238': 66,
#          '20259': 27,
#          '20270': 27,
#          '102723': 30,
#          '1540': 19,
#          '1564': 3,
#          '1565': 8,
#          '1615': 75,
#          '1618': 19,
#          '1969': 13,
#          '2459': 18,
#          '728': 4,
#          '831': 18,
#          '1620': 10,
# ...

# %%
doctorOrders_to_int = {code:ii for ii,code in enumerate(doctor_orders_counter,1)}
doctorOrders_to_int
# Out:
# {'2434': 1,
#  '101032': 2,
#  '1623': 3,
#  '1645': 4,
#  '2405': 5,
#  '23895': 6,
#  '24130': 7,
#  '23005': 8,
#  '20436': 9,
#  '23261': 10,
#  '23264': 11,
#  '23282': 12,
#  '23286': 13,
#  '23294': 14,
#  '23296': 15,
#  '23298': 16,
#  '23300': 17,
#  '23302': 18,
#  '23304': 19,
#  '23310': 20,
#  '23314': 21,
#  '23316': 22,
#  '23318': 23,
#  '23324': 24,
#  '23326': 25,
#  '23361': 26,
#  '23364': 27,
#  '23253': 28,
#  '20238': 29,
#  '20259': 30,
#  '20270': 31,
#  '102723': 32,
#  '1540': 33,
#  '1564': 34,
#  '1565': 35,
#  '1615': 36,
#  '1618': 37,
#  '1969': 38,
#  '2459': 39,
#  '728': 40,
#  '831': 41,
#  '1620': 42,
#  '2299': 43,
#  '701': 44,
#  '20431': 45,
#  '23348': 46,
#  '23350': 47,
#  '23496': 48,
#  '25120': 49,
#  '23214': 50,
#  '23224': 51,
#  '23228': 52,
#  '23236': 53,
#  '23246': 54,
#  '23250': 55,
#  '1079': 56,
#  '2100': 57,
#  '657': 58,
#  '2007': 59,
#  '537': 60,
#  '20981': 61,
#  '20988': 62,
#  '20992': 63,
#  '20402': 64,
# ...

# %%
doctorOrders_ints = [doctorOrders_to_int[x] for x in doctor_orders]
len(doctorOrders_ints)
# Out:
# 3601

# %% [markdown]
# # 3.1.2 诊断数据相关处理

# %%
df_join_exam_and_doctorOrderDetail_exact['diagnose_words'] = df_join_exam_and_doctorOrderDetail_exact['REPORTDIAGNOSE'].map(lambda x: list(jieba.cut(x)))

df_join_exam_and_doctorOrderDetail_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 1         483018.0  2017年8月30日20:06:15\n急诊报告：\n1、慢性支气管炎、肺气肿征象。\n2、...
# 2         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 3         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 4         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 1  1、慢性支气管炎、肺气肿征象。\n2、左肺上叶尖后段局部支气管扩张。\n3、双肺上叶尖（后）...
# 2  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 3  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 4  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 1  [2017, 年, 8, 月, 30, 日, 20, :, 06, :, 15, \n, 急...
# 2  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# ...

# %%
diagnose_words_lists = df_join_exam_and_doctorOrderDetail_exact['diagnose_words'].values
diagnose_all_words = np.hstack(diagnose_words_lists)
diagnose_word_bag = set(diagnose_all_words)
diagnose_word_bag
# Out:
# {'\n',
#  ' ',
#  ',',
#  '-',
#  '.',
#  '/',
#  '0.3',
#  '0.4',
#  '0.7',
#  '0.8',
#  '1',
#  '1.1',
#  '1.2',
#  '1.4',
#  '1.5',
#  '1.6',
#  '10',
#  '10.6',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '2',
#  '2.0',
#  '2.4',
#  '2.5',
#  '2.7',
#  '2.8',
#  '2.9',
#  '20%',
#  '2mm',
#  '3',
#  '3.4',
#  '3.70',
#  '3.8',
#  '37mm',
#  '39mm',
#  '4',
#  '4.3',
#  '4.43',
#  '4.6',
#  '45mm',
#  '4mm',
#  '5',
#  '5%',
#  '5.0',
#  '5.2',
#  '5.4',
#  '5mm',
#  '6',
#  '7',
#  '7mm',
#  '8',
#  '9',
#  'B超',
#  'CT',
#  'CTA',
#  'I',
#  'MR',
#  'MRI',
#  'S1',
#  'X',
#  'cm',
#  'cmX1.3',
#  '°',
#  '·',
#  '×',
#  'Ⅰ',
#  '、',
#  '。',
#  '一',
#  '一枚',
#  '一类',
#  '三维',
#  '上',
#  '上叶',
#  '上叶后',
#  '上极见',
#  '上述',
#  '上野',
#  '上颌',
#  '下',
#  '下及',
#  '下叶',
#  '下散',
#  '下方',
#  '下段',
#  '下肢',
#  '下腔',
#  '下腹',
#  '下见',
#  '下野',
#  '不',
#  '不佳',
#  '不大',
#  '不张',
#  '不清',
#  '不能',
#  '不规则',
#  '与',
#  '丘脑',
#  '两',
#  '两肺',
#  '中',
#  '中内',
#  '中叶',
#  '中度',
# ...

# %%
len(diagnose_word_bag)
# Out:
# 897

# %%
diagnose_counts = Counter(diagnose_word_bag)
diagnose_vocab = sorted(diagnose_counts, key=diagnose_counts.get, reverse=True)
diagnose_vocab_to_int = {word:ii for ii, word in enumerate(diagnose_vocab, 1)}

diagnose_ints = []
for each in diagnose_words_lists:
    diagnose_ints.append([diagnose_vocab_to_int[word] for word in each])

# %%
diagnose_vocab_to_int
# Out:
# {'特异性': 1,
#  '征': 2,
#  '分界': 3,
#  '结晶体': 4,
#  '骨瘤': 5,
#  '少量': 6,
#  '侵犯': 7,
#  '变影': 8,
#  '下野': 9,
#  '感染': 10,
#  '病人': 11,
#  '包裹': 12,
#  '未见': 13,
#  '所示': 14,
#  '确切': 15,
#  '皮层': 16,
#  '枕部': 17,
#  '肠壁': 18,
#  '空洞': 19,
#  '系统': 20,
#  '肺散': 21,
#  '蝶骨': 22,
#  '陈旧性': 23,
#  '及主': 24,
#  '见小斑': 25,
#  '慢性感染': 26,
#  '胃肠': 27,
#  '下': 28,
#  '简直': 29,
#  '狭窄': 30,
#  '其它': 31,
#  '肾囊肿': 32,
#  '右侧': 33,
#  '气管炎': 34,
#  '外形': 35,
#  '被': 36,
#  '强': 37,
#  '偏曲': 38,
#  '空肠': 39,
#  '复查': 40,
#  '腔隙性': 41,
#  '区': 42,
#  '肺动脉': 43,
#  '集合': 44,
#  '区域': 45,
#  '5.0': 46,
#  '左支': 47,
#  '蝶窦': 48,
#  '及桥': 49,
#  '不能': 50,
#  'Ⅰ': 51,
#  '膝降': 52,
#  '及叶间': 53,
#  '邻近': 54,
#  '排外': 55,
#  '有无': 56,
#  '进一步': 57,
#  '腹股沟': 58,
#  '肺门影': 59,
#  '血管': 60,
#  '实变': 61,
#  '侵润': 62,
#  '主干': 63,
#  '\n': 64,
#  '体未见': 65,
#  '管影': 66,
#  '胃腔': 67,
#  '玻璃': 68,
#  '肌及': 69,
#  '外侧': 70,
#  '管状': 71,
#  '损害': 72,
#  '底部': 73,
#  '置入': 74,
#  '结核': 75,
#  '精囊': 76,
# ...

# %%
diagnose_ints
# Out:
# [[288,
#   431,
#   456,
#   642,
#   42,
#   431,
#   689,
#   42,
#   763,
#   798,
#   504,
#   711,
#   497,
#   100,
#   246,
#   201,
#   775,
#   64,
#   356,
#   431,
#   442,
#   526,
#   503,
#   775,
#   64,
#   102,
#   431,
#   840,
#   683,
#   210,
#   96,
#   221,
#   225,
#   775],
#  [288,
#   431,
#   314,
#   566,
#   431,
#   469,
#   262,
#   775,
#   64,
#   356,
#   431,
#   610,
#   437,
#   475,
#   155,
#   838,
#   795,
#   764,
#   585,
#   775,
#   64,
#   102,
#   431,
#   345,
#   437,
#   475,
#   656,
#   155,
#   865,
#   838,
#   192,
#   775,
#   64,
#   710,
#   431,
#   610,
#   437,
#   362,
#   303,
#   668,
#   370,
#   504,
#   711,
#   497,
#   684,
#   862,
#   711,
#   118,
#   415,
#   155,
#   40,
#   775,
#   64,
#   359,
#   431,
#   142,
#   523,
#   711,
#   249,
#   890,
#   556,
#   734,
#   234,
#   870,
#   775,
#   64,
#   852,
#   431,
#   456,
#   717,
#   255,
#   431,
#   648,
#   775,
#   64,
#   676,
#   431,
#   765,
# ...

# %%
diagnose_lens = Counter([len(diagnose) for diagnose in diagnose_ints])
max(diagnose_lens)
# Out:
# 256

# %%
df_join_exam_and_doctorOrderDetail_exact['diagnose_ints'] = diagnose_ints
df_join_exam_and_doctorOrderDetail_exact.head()
# Out:
#    OUTP_PATIENT_NO                                     REPORTDESCRIBE  \
# 0         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 1         483018.0  2017年8月30日20:06:15\n急诊报告：\n1、慢性支气管炎、肺气肿征象。\n2、...
# 2         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 3         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
# 4         483018.0  急诊报告\n2017年8月15日15:50:46\n1、双侧基底节区、脑干区点状低密度影，考...
#
#                                       REPORTDIAGNOSE  \
# 0  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 1  1、慢性支气管炎、肺气肿征象。\n2、左肺上叶尖后段局部支气管扩张。\n3、双肺上叶尖（后）...
# 2  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 3  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
# 4  1、双侧基底节区、脑干区点状低密度影，考虑为腔隙性脑梗塞。\n2、老年性脑改变。\n3、CT...
#
#                                    describe_wordlist  \
# 0  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# 1  [2017, 年, 8, 月, 30, 日, 20, :, 06, :, 15, \n, 急...
# 2  [急诊, 报告, \n, 2017, 年, 8, 月, 15, 日, 15, :, 50, ...
# ...

# %%
df_join_exam_and_doctorOrderDetail_exact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3601 entries, 0 to 3600
# Data columns (total 11 columns):
# OUTP_PATIENT_NO      3601 non-null float64
# REPORTDESCRIBE       3601 non-null object
# REPORTDIAGNOSE       3601 non-null object
# describe_wordlist    3601 non-null object
# describe_keywords    3601 non-null object
# SERIAL_NO            3601 non-null int64
# ITEM_CODE            3601 non-null object
# ITEM_NAME            3601 non-null object
# describe_ints        3601 non-null object
# diagnose_words       3601 non-null object
# diagnose_ints        3601 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 337.6+ KB

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from keras import callbacks
import numpy as np

# 基本参数
batch_size = 64
epochs = 100
latent_dim = 256 # LSTM 的单元个数
num_samples = 3601 # 训练样本的大小

# %%
max_encoder_seq_length = max([ len(txt) for txt in df_join_exam_and_doctorOrderDetail_exact['describe_ints']])
max_decoder_seq_length = max([ len(txt) for txt in df_join_exam_and_doctorOrderDetail_exact['diagnose_ints']])

print("max_encoder_seq_length:",max_encoder_seq_length)
print("max_decoder_seq_length:",max_decoder_seq_length)
# Out:
# max_encoder_seq_length: 391
# max_decoder_seq_length: 256

# %%
# 创建数组 
encoder_input_data = np.zeros((num_samples, max_encoder_seq_length, len(describe_word_bag)+1), dtype=np.float32)
decoder_input_data = np.zeros((num_samples, max_decoder_seq_length, len(diagnose_word_bag)+1), dtype=np.float32)
decoder_target_data = np.zeros((num_samples, max_decoder_seq_length, len(diagnose_word_bag)+1), dtype=np.float32)

# 填充数据, 对每一个单词做one-hot
for i, (input_text, target_text) in enumerate(zip(df_join_exam_and_doctorOrderDetail_exact['describe_ints'], df_join_exam_and_doctorOrderDetail_exact['diagnose_ints'])):
    # 对编码器的输入序列做one-hot
    for t, word in enumerate(input_text):
        encoder_input_data[i, t, word] = 1.0

    # 对解码器的输入与输出做序列做one-hot
    for t, word in enumerate(target_text):
        decoder_input_data[i, t, word] = 1.0

        if t > 0:
            # decoder_target_data 不包含开始字符，并且比decoder_input_data提前一步
            decoder_target_data[i, t-1, word] = 1.0

# %%
# 定义编码器的输入
# encoder_inputs (None, num_encoder_tokens), None表示可以处理任意长度的序列
encoder_inputs = Input(shape=(None, len(describe_word_bag)+1))

# 编码器，要求其返回状态
encoder = LSTM(latent_dim, return_state=True)

# 调用编码器，得到编码器的输出（输入其实不需要），以及状态信息 state_h 和 state_c
encoder_outpus, state_h, state_c = encoder(encoder_inputs)

# 丢弃encoder_outputs, 我们只需要编码器的状态
encoder_state = [state_h, state_c]

# %%
# 定义解码器的输入
# 同样的，None表示可以处理任意长度的序列
decoder_inputs = Input(shape=(None, len(diagnose_word_bag)+1))

# 接下来建立解码器，解码器将返回整个输出序列
# 并且返回其中间状态，中间状态在训练阶段不会用到，但是在推理阶段将是有用的
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

# 将编码器输出的状态作为初始解码器的初始状态
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_state)

# 添加全连接层
decoder_dense = Dense(len(diagnose_word_bag)+1, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# 定义整个模型
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# 定义回调函数
#callback_list = [callbacks.EarlyStopping(patience=10)]
# 编译模型
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# 训练
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs = epochs,
          validation_split=0.2)

# 保存模型
model.save('tp_dl.h5')
# Out:
# Train on 2880 samples, validate on 721 samples
# Epoch 1/100

# %%
# 定义 sampling 模型
# 定义 encoder 模型，得到输出encoder_states
encoder_model = Model(encoder_inputs, encoder_state)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# 得到解码器的输出以及中间状态
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs]+decoder_states)

# %%
# 建立 数字->字符 的字典，用于恢复
reverse_input_char_index = dict([(i, char) for char, i in input_token_index.items()])
reverse_target_char_index = dict([(i, char) for char, i in target_token_index.items()])

# %%
def decode_sequence(input_seq):
    # 将输入序列进行编码
    states_value = encoder_model.predict(input_seq)

    # 生成一个size=1的空序列
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # 将这个空序列的内容设置为开始字符
    target_seq[0, 0, target_token_index['\t']] = 1.

    # 进行字符恢复
    # 简单起见，假设batch_size = 1
    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # 退出条件：生成 \n 或者 超过最大序列长度
        if sampled_char == '\n' or len(decoded_sentence) > max_decoder_seq_length :
            stop_condition = True

        # 更新target_seq
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # 更新中间状态
        states_value = [h, c]

    return decoded_sentence

# %%
# 检验成果的时候到了,从训练集中选取一些句子做测试
# 效果还行（废话，从训练集里挑的数据）
for seq_index in range(1000, 1100):
    # batch_size = 1
    input_seq = encoder_input_data[seq_index:seq_index+1]
    decoded_sentence = decode_sequence(input_seq)

    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)

# %% [markdown]
# # 4.2 旧版训练、验证、测试数据集分割(以下暂时弃用）

# %%
split_frac = 0.8
split_idx = int(len(features)*split_frac)
train_x, val_x = features[:split_idx], features[split_idx:]
train_y, val_y = doctorOrders_ints[:split_idx], doctorOrders_ints[split_idx:]

test_idx = int(len(val_x)*0.5)
val_x, test_x = val_x[:test_idx], val_x[test_idx:]
val_y, test_y = val_y[:test_idx], val_y[test_idx:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(2880, 391)
# Validation set: 	(360, 391)
# Test set: 		(361, 391)

# %%
lstm_size = 256
lstm_layers = 1
batch_size = 30
learning_rate = 0.001

# %%
n_words = len(vocab_to_int)+1

graph = tf.Graph()
with graph.as_default():
    inputs_ = tf.placeholder(tf.int32, [None, None], name='inputs')
    labels_ = tf.placeholder(tf.int32, [None, None], name='labels')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# %%
embed_size = 300
with graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
with graph.as_default():
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * lstm_layers)
    initial_state = cell.zero_state(batch_size, tf.float32)

# %%
with graph.as_default():
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)

# %%
with graph.as_default():
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    cost = tf.losses.mean_squared_error(labels_, predictions)
    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
with graph.as_default():
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred,tf.float32))

# %%
def get_batches(x, y, batch_size=100):
    n_batches = len(x) // batch_size
    x, y = x[:n_batches * batch_size], y[:n_batches * batch_size]
    for i in range(n_batches):
        yield x[i*batch_size:(i+1)*batch_size], y[i*batch_size:(i+1)*batch_size]

# %%
epochs = 10

with graph.as_default():
    saver = tf.train.Saver()
    
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size = batch_size), 1):
            feed = {
                inputs_: x,
                labels_: [y],
                keep_prob: 0.8,
                initial_state: state
            }
            loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)
            
            if iteration % 5 == 0:
                print('Epoch: {}/{}'.format(e, epochs),
                     'Iteration: {}'.format(iteration),
                     'Train loss: {:.3f}'.format(loss))
                
            if iteration % 25 == 0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x,y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: [y],
                            keep_prob: 1,
                            initial_state: val_state}
                    batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
    saver.save(sess, 'checkpoints/tpdl.ckpt')
# Out:
# Epoch: 0/10 Iteration: 5 Train loss: 2146.711
# Epoch: 0/10 Iteration: 10 Train loss: 2588.467
# Epoch: 0/10 Iteration: 15 Train loss: 1059.967
# Epoch: 0/10 Iteration: 20 Train loss: 1584.133
# Epoch: 0/10 Iteration: 25 Train loss: 7181.000
# Val acc: 0.000
# Epoch: 0/10 Iteration: 30 Train loss: 2763.300
# Epoch: 0/10 Iteration: 35 Train loss: 3542.600
# Epoch: 0/10 Iteration: 40 Train loss: 13681.500
# Epoch: 0/10 Iteration: 45 Train loss: 3174.533
# Epoch: 0/10 Iteration: 50 Train loss: 1236.567
# Val acc: 0.000
# Epoch: 0/10 Iteration: 55 Train loss: 2222.400
# Epoch: 0/10 Iteration: 60 Train loss: 250.500
# Epoch: 0/10 Iteration: 65 Train loss: 6739.633
# Epoch: 0/10 Iteration: 70 Train loss: 10053.500
# Epoch: 0/10 Iteration: 75 Train loss: 8461.733
# Val acc: 0.000
# Epoch: 0/10 Iteration: 80 Train loss: 3843.033
# Epoch: 0/10 Iteration: 85 Train loss: 3497.600
# Epoch: 0/10 Iteration: 90 Train loss: 3338.800
# Epoch: 0/10 Iteration: 95 Train loss: 5066.000
# ...
