# %%
import pandas as pd
from Network_cluster import Net_Spectral_clustering,Net_Hierarchical_clustering,Net_Fast_Unfolding
import scipy
import scipy.cluster.hierarchy as sch
from scipy.cluster.vq import vq,kmeans,whiten 
import matplotlib as mlp
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-e87ff0616c6b> in <module>()
# ----> 1 import pandas as pd
#       2 from Network_cluster import Net_Spectral_clustering,Net_Hierarchical_clustering,Net_Fast_Unfolding
#       3 import scipy
#       4 import scipy.cluster.hierarchy as sch
#       5 from scipy.cluster.vq import vq,kmeans,whiten
#
# D:\Anaconda3\lib\site-packages\pandas\__init__.py in <module>()
#      17 if missing_dependencies:
#      18     raise ImportError(
# ---> 19         "Missing required dependencies {0}".format(missing_dependencies))
#      20 del hard_dependencies, dependency, missing_dependencies
#      21
#
# ImportError: Missing required dependencies ['numpy']

# %%
df_doctor_order = pd.read_csv('7_inhospital_doctor_order_detail.csv')
df_doctor_order.head()
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (12,13,14,19,22,23,32,33,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    HOSPITAL_CODE       PATIENT_ID  PATIENT_NO  INPATIENT_NO  SERIAL_NO  \
# 0    43120181600  5300-0099001298     8007713          9311     256100
# 1    43120181600  5300-0099001298     8007713          9311     256101
# 2    43120181600  5300-0000043212     8007056          8562     271084
# 3    43120181600       0102086714     8007680          9272     255438
# 4    43120181600       0102086714     8007680          9272     255439
#
#    ITEM_SNOMED  SN_COMMENT  ITEM_CODE  MO_NAME  EMP_NO    ...     EXEC_DPNM  \
# 0          NaN         NaN        391  骨化三醇软胶囊   30212    ...         干部保健科
# 1          NaN         NaN        292   碳酸钙D3片   30212    ...         干部保健科
# 2          NaN         NaN     101085    酚氨咖敏片   26390    ...          神经内科
# 3          NaN         NaN       1615    5%葡萄糖   30348    ...          呼吸内科
# 4          NaN         NaN       2152   溴己新盐酸盐   30348    ...          呼吸内科
#
#                      UPDATED_ON   SEQ_ID SYS_EMP_NO DATA_VERSION  SYS_MO_NAME  \
# 0  24-5月 -18 03.20.51.000000 下午  1031512   13030212            0          NaN
# 1  24-5月 -18 03.20.51.000000 下午  1031513   13030212            0          NaN
# 2  24-5月 -18 03.20.51.000000 下午  1031515   13026390            0          NaN
# 3  24-5月 -18 03.20.51.000000 下午  1031519   13030348            0          NaN
# 4  24-5月 -18 03.20.51.000000 下午  1031520   13030348            0          溴己新
#
#   SYS_DOSE_UNIT SYS_UNIT  SYS_USE_NAME ITEM_CLASS
# 0           NaN      NaN            口服        NaN
# 1           NaN      NaN            口服        NaN
# 2           NaN      NaN            口服        NaN
# 3            mL      NaN           NaN        NaN
# 4            mg      NaN           NaN        NaN
#
# [5 rows x 37 columns]

# %%
df_extracted = df_doctor_order[['INPATIENT_NO','ITEM_CODE']]
df_extracted.head()
# Out:
#    INPATIENT_NO  ITEM_CODE
# 0          9311        391
# 1          9311        292
# 2          8562     101085
# 3          9272       1615
# 4          9272       2152

# %%
Net_Spectral_clustering(df_extracted, nclusters=3, affinity_v='rbf')
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\manifold\spectral_embedding_.py:234: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-51df8e901fb4> in <module>()
# ----> 1 Net_Spectral_clustering(df_extracted, nclusters=3, affinity_v='rbf')
#
# \\tsclient\C\Users\Acer\tp_project\Network_cluster.py in Net_Spectral_clustering(data, nclusters, affinity_v)
#     271     # 谱聚类
#     272     nclusters=nclusters
# --> 273     ADJ_Spectral_clustering, max_score_nclusters,y_pred = Self_spectral_clustering(data,nclusters,affinity_v)
#     274
#     275     # 获取每个类别的具体内容,
#
# \\tsclient\C\Users\Acer\tp_project\Network_cluster.py in Self_spectral_clustering(Matrix, nclusters, affinity_v)
#     220             # 输入的数据默认应该用原始数据，如果要用邻接矩阵作为输入数据，那么就应该设置 affinity='precomputed'
#     221             y_pred = SpectralClustering(n_clusters=k, affinity=affinity_v).fit_predict(
# --> 222                 ADJ_Spectral_clustering)
#     223             score = metrics.calinski_harabaz_score(ADJ_Spectral_clustering, y_pred)
#     224             if score > max_score:
#
# D:\Anaconda3\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     408         # non-optimized default implementation; override when a better
#     409         # method is possible for a given clustering algorithm
# --> 410         self.fit(X)
#     411         return self.labels_
#     412
#
# D:\Anaconda3\lib\site-packages\sklearn\cluster\spectral.py in fit(self, X, y)
#     470                                            n_init=self.n_init,
#     471                                            eigen_tol=self.eigen_tol,
# --> 472                                            assign_labels=self.assign_labels)
#     473         return self
#     474
#
# D:\Anaconda3\lib\site-packages\sklearn\cluster\spectral.py in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels)
#     260                               eigen_solver=eigen_solver,
#     261                               random_state=random_state,
# --> 262                               eigen_tol=eigen_tol, drop_first=False)
#     263
#     264     if assign_labels == 'kmeans':
#
# D:\Anaconda3\lib\site-packages\sklearn\manifold\spectral_embedding_.py in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     268             lambdas, diffusion_map = eigsh(laplacian, k=n_components,
#     269                                            sigma=1.0, which='LM',
# --> 270                                            tol=eigen_tol, v0=v0)
#     271             embedding = diffusion_map.T[n_components::-1] * dd
#     272         except RuntimeError:
#
# D:\Anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1649     with _ARPACK_LOCK:
#    1650         while not params.converged:
# -> 1651             params.iterate()
#    1652
#    1653         return params.extract(return_eigenvectors)
#
# D:\Anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in iterate(self)
#     557             else:
#     558                 Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 559                 self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     560         elif self.ido == 2:
#     561             self.workd[yslice] = self.B(self.workd[xslice])
#
# D:\Anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in matvec(self, x)
#     217             raise ValueError('dimension mismatch')
#     218
# --> 219         y = self._matvec(x)
#     220
#     221         if isinstance(x, np.matrix):
#
# D:\Anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in _matvec(self, x)
#     934
#     935     def _matvec(self, x):
# --> 936         return lu_solve(self.M_lu, x)
#     937
#     938
#
# D:\Anaconda3\lib\site-packages\scipy\linalg\decomp_lu.py in lu_solve(lu_and_piv, b, trans, overwrite_b, check_finite)
#     144
#     145     getrs, = get_lapack_funcs(('getrs',), (lu, b1))
# --> 146     x, info = getrs(lu, piv, b1, trans=trans, overwrite_b=overwrite_b)
#     147     if info == 0:
#     148         return x
#
# KeyboardInterrupt:

# %%
Net_Hierarchical_clustering(df_extracted, cutoff = 0.3,metric_name='jaccard')

# %%
Net_Fast_Unfolding(df_extracted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9fce40106f5a> in <module>()
# ----> 1 Net_Fast_Unfolding(df_extracted)
#
# NameError: name 'Net_Fast_Unfolding' is not defined
