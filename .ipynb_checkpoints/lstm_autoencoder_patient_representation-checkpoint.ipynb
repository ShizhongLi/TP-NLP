# %%
import torch
import jieba.posseg as pseg
import codecs
from gensim import corpora, models, similarities
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
# Out:
# D:\program\Anaconda\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
df_record = pd.read_csv('admission_mr.csv')
df_record.head()
# Out:
#         ID  SYSTYPE DATATYPE  PATIENT_ID  PATIENT_NO    INPATIENT_NO INDEX2  \
# 0  2199335        0     入院相关  0000545965      287627  ZY170000287627    曾*忠
# 1  2199335        0     入院相关  0000545965      287627  ZY170000287627    曾*忠
# 2  2199339        0     入院相关  0000545965      287627  ZY170000287627    曾*忠
# 3  2199339        0     入院相关  0000545965      287627  ZY170000287627    曾*忠
# 4  2199339        0     入院相关  0000545965      287627  ZY170000287627    曾*忠
#
#       PARENTNODENAME NODENAME NODEVALUE       ...        OPERATOR_NAME  \
# 0  入院病历\病史\既往史\手术外伤史    手术外伤史       NaN       ...                 何梦璋*
# 1      入院病历\个人史\一般情况     一般情况       NaN       ...                 何梦璋*
# 2   入院病历\体格检查一般情况\体位       体位        自主       ...                 何梦璋*
# 3    入院病历\体格检查头面部\口唇       口唇        正常       ...                 何梦璋*
# 4    入院病历\体格检查颈部\甲状腺      甲状腺        未及       ...                 何梦璋*
#
#              OPERATOR_TIME       NAME                    UPDATED_ON  \
# 0  2012/12/27 星期四 12:56:41  再次或多次入院记录  05-6月 -18 02.53.06.000000 下午
# 1  2012/12/27 星期四 12:56:41  再次或多次入院记录  05-6月 -18 02.53.06.000000 下午
# 2  2012/12/27 星期四 12:59:44  再次或多次入院记录  05-6月 -18 02.53.06.000000 下午
# 3  2012/12/27 星期四 12:59:44  再次或多次入院记录  05-6月 -18 02.53.06.000000 下午
# 4  2012/12/27 星期四 12:59:44  再次或多次入院记录  05-6月 -18 02.53.06.000000 下午
#
#   PROCESS_STATUS  SEQ_ID       HOSPITAL_CODE OPERATOR_SYS_EMP_NO  \
# 0            NaN   31543  12440100455344205E                 NaN
# 1            NaN   31544  12440100455344205E                 NaN
# 2            NaN   31040  12440100455344205E                 NaN
# 3            NaN   31041  12440100455344205E                 NaN
# 4            NaN   31042  12440100455344205E                 NaN
#
#    DATA_VERSION  INP_PATIENT_NO
# 0             0             NaN
# 1             0             NaN
# 2             0             NaN
# 3             0             NaN
# 4             0             NaN
#
# [5 rows x 21 columns]

# %%
df_patient_disease_record = df_record[df_record['NODENAME'] == '现病史']
print(len(df_patient_disease_record))
df_patient_disease_record.head()
# Out:
# 1630
#           ID  SYSTYPE DATATYPE  PATIENT_ID  PATIENT_NO    INPATIENT_NO INDEX2  \
# 275  2318913        0     入院相关  0080324728      365305  ZY010000365305    黄*强
# 315  2294384        0     入院相关  0000749211      321757  ZY060000321757    陈*成
# 347  2329240        0     入院相关  0000033445      280478  ZY110000280478    吴*伙
# 353  2329166        0     入院相关  0000033445      280478  ZY110000280478    吴*伙
# 416  2333860        0     入院相关  0080326996      365630  ZY010000365630    张*焕
#
#     PARENTNODENAME NODENAME  \
# 275    入院病历\病史\现病史      现病史
# 315    入院病历\病史\现病史      现病史
# 347    入院病历\病史\现病史      现病史
# 353    入院病历\病史\现病史      现病史
# 416    入院病历\病史\现病史      现病史
#
#                                              NODEVALUE       ...        \
# 275  患者1周前无明显诱因开始出现发热，最高体温37.9℃，无伴畏寒、寒战、皮疹，无明显时间规律，...       ...
# 315  患者2010-11因咳嗽咳痰就诊于当地医院，行胸部CT提示1、考虑双肺矽肺并双侧局部胸膜增厚...       ...
# 347  患者7年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...       ...
# 353  患者5年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...       ...
# 416  患者2月余前外伤致右胸疼痛伴全身多处疼痛，当时至梅州市人民医院就诊，胸部CT提示：“右侧血气...       ...
#
#      OPERATOR_NAME           OPERATOR_TIME       NAME  \
# 275            张鹤*  2013/2/28 星期四 16:54:40       入院记录
# 315           叶枫**  2013/2/16 星期六 16:49:07       入院记录
# 347           朱琳**   2013/3/6 星期三 23:18:27    中医科入院记录
# 353            李振球   2013/3/5 星期二 16:38:59  再次或多次入院记录
# 416            李树本   2013/3/7 星期四 15:20:27       入院记录
#
#                        UPDATED_ON PROCESS_STATUS  SEQ_ID       HOSPITAL_CODE  \
# 275  05-6月 -18 02.53.06.000000 下午            NaN   86784  12440100455344205E
# 315  05-6月 -18 02.53.06.000000 下午            NaN   89457  12440100455344205E
# 347  05-6月 -18 02.53.06.000000 下午            NaN  104804  12440100455344205E
# 353  05-6月 -18 02.53.06.000000 下午            NaN  104333  12440100455344205E
# 416  05-6月 -18 02.53.06.000000 下午            NaN  103666  12440100455344205E
#
#     OPERATOR_SYS_EMP_NO  DATA_VERSION  INP_PATIENT_NO
# 275                 NaN             0             NaN
# 315                 NaN             0             NaN
# 347                 NaN             0             NaN
# 353                 NaN             0             NaN
# 416                 NaN             0             NaN
#
# [5 rows x 21 columns]

# %%
df_patient_disease_record_extracted = df_patient_disease_record[['INPATIENT_NO','NODEVALUE']]
print(len(df_patient_disease_record_extracted))
df_patient_disease_record_extracted.head()
# Out:
# 1630
#        INPATIENT_NO                                          NODEVALUE
# 275  ZY010000365305  患者1周前无明显诱因开始出现发热，最高体温37.9℃，无伴畏寒、寒战、皮疹，无明显时间规律，...
# 315  ZY060000321757  患者2010-11因咳嗽咳痰就诊于当地医院，行胸部CT提示1、考虑双肺矽肺并双侧局部胸膜增厚...
# 347  ZY110000280478  患者7年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...
# 353  ZY110000280478  患者5年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...
# 416  ZY010000365630  患者2月余前外伤致右胸疼痛伴全身多处疼痛，当时至梅州市人民医院就诊，胸部CT提示：“右侧血气...

# %%
df_patient_disease_record_extracted = df_patient_disease_record_extracted.drop_duplicates(['INPATIENT_NO'])
print(len(df_patient_disease_record_extracted))
# Out:
# 1479

# %%
df_patient_disease_record_extracted = df_patient_disease_record_extracted.dropna()
print(len(df_patient_disease_record_extracted))
# Out:
# 1421

# %%
words_record_list = []
for each in df_patient_disease_record_extracted['NODEVALUE']:
    temp_word_list = []
    words = pseg.cut(each)
    for word, flag in words:
        temp_word_list.append(word)
    words_record_list.append(temp_word_list)
    
print(words_record_list[:100])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Acer\AppData\Local\Temp\jieba.cache
# Loading model cost 0.895 seconds.
# Prefix dict has been built succesfully.
# [['患者', '1', '周前', '无', '明显', '诱因', '开始', '出现', '发热', '，', '最高', '体温', '37.9', '℃', '，', '无伴', '畏寒', '、', '寒战', '、', '皮疹', '，', '无', '明显', '时间', '规律', '，', '伴', '咳嗽', '，', '连声', '咳', '，', '伴咳', '黄色', '粘', '痰', '，', '无', '血丝', '，', '量', '一般', '，', '无', '明显', '时间', '规律', '，', '伴', '气促', '，', '无伴', '胸闷', '、', '心悸', '，', '无伴', '恶心', '、', '呕吐', '、', '腹痛', '、', '腹胀', '、', '腹泻', '，', '无伴', '尿频', '、', '尿急', '、', '尿痛', '，', '未予', '特殊', '处理', '，', '现', '为', '进一步', '诊治', '遂', '至', '我院', '就诊', '，', '查', '血常规', '：', '白细胞', '计数', '：', '16.49', '*', '10', '^', '9', '/', 'L', ',', '中性', '粒细胞', '比率', ':', '80.1', '%', '，', '胸片', '：', '两', '肺', '纹理', '增', '粗', '增多', '，', '拟', '两下', '肺', '散', '在', '少许', '炎症', '，', '门诊', '拟', '“', '双', '下', '肺炎', '”', '收治', '我', '科', '。', '患者', '自', '起病', '来', '，', '精神', '、', '睡眠', '尚可', '，', '胃纳', '一般', '，', '大小便', '如常', '，', '近期', '体重', '无', '明显', '变化', '。'], ['患者', '2010', '-', '11', '因', '咳嗽', '咳痰', '就诊', '于', '当地', '医院', '，', '行', '胸部', 'CT', '提示', '1', '、', '考虑', '双', '肺', '矽肺', '并', '双侧', '局部', '胸膜', '增厚', '粘连', '2', '、', '左', '肺', '支气管', '扩张', '并', '感染', '3', '、', '纵隔', '及', '右肺', '门', '淋巴结', '稍', '大', '，', '予', '抗感染', '（', '具体', '不详', '）', '对症', '治疗', '后', '，', '咳嗽', '、', '咳痰', '及', '活动', '后', '气促', '症状', '无', '明显改善', '，', '2011', '-', '2', '在', '我院', '行', '纤维', '支气管镜', '活检', '病理', '报告', '回', '：', '（', '左主', '支气管', '）', '中', '分化', '鳞状', '细胞', '癌', '，', '于', '22', '/', '2', '行', '纤维', '支气管镜', '下', '支气管', '扩张', '及', '冰冻', '治疗', '术', '。', '于', '2', '/', '3', '、', '22', '/', '3', '，', '19', '/', '4', '、', '12', '/', '5', '予以', 'GP', '方案', '化疗', '。', '化疗', '过程', '顺利', '。', '2011', '-', '6', '月', '至', '2011', '-', '7', '月', '行', '肺部', '病灶', '放疗', '。', '出院', '后', '规律', '服用', '药物', '治疗', '，', '间有', '咳嗽', '、', '咳痰', '。', '近', '一周', '，', '患者', '咳嗽', '咳痰', '气促', '加重', '，', '续来', '我院', '呼吸', '内科', '一', '区', '住院治疗', '，', '精神', '倦', '，', '睡眠', '差', '，', '胃', '纳少', '，', '二', '便', '正常', '。'], ['患者', '7', '年前', '无', '明显', '诱因', '出现', '咳嗽', '、', '咳痰', '，', '为', '阵发性', '咳', '，', '咳声', '高亢', '，', '少量', '白', '泡沫痰', '，', '尚可', '咯出', '，', '伴', '气促', '，', '以', '活动', '后', '为', '甚', '，', '每', '于', '受凉', '后', '为', '甚', '，', '平卧', '休息', '不', '缓解', '，', '咳嗽', '与', '吸入', '油烟', '等', '刺激性', '气体', '无关', '，', '每年', '累计', '发作', '时间', '大于', '3', '个', '月', '。', '曾', '于', '我院', '诊断', '为', '“', 'COPD', '”', '，', '予', '“', '舒利', '迭', '、', '可', '必特', '”', '“', '美卓乐', '”', '等', '药行', '平喘', '治疗', '，', '症状', '稍', '缓解', '，', '但', '7', '年来', '上述', '症状', '仍', '反复', '发作', '，', '并', '呈', '进行性', '加重', '。', '10', '天前', '受凉', '后', '再', '发', '咳嗽', '、', '咳痰', '，', '为', '黄白色', '粘', '痰', '，', '气促', '较', '前', '加重', '，', '伴', '恶寒', '，', '无', '心悸', '，', '无', '下肢', '浮肿', '，', '夜间', '能', '平卧', '，', '无', '夜间', '阵发性', '呼吸困难', '，', '今', '为', '进一步', '诊治', '诊拟', '“', '慢性', '阻塞性', '肺气肿', '急性', '加重', '期', '”', '收入', '我', '科', '。', '现', '患者', '咳嗽', '、', '咳痰', '伴', '气促', '，', '咳声', '高亢', '，', '咳', '黄白色', '粘', '痰', '，', '气促', '较', '前', '加重', '，', '咽', '痒', '，', '诉掌', '指关节', '疼痛', '，', '无', '发热', '，', '无', '头晕', '，', '无', '恶心', '呕吐', '，', '无', '胸痛', '心悸', '，', '起病', '以来', '胃', '纳差', '，', '睡眠', '欠佳', '，', '二', '便', '尚可', '。', '近来', '体重', '无', '明显', '变化', '。'], ['患者', '2', '月余', '前', '外伤', '致', '右', '胸', '疼痛', '伴', '全身', '多处', '疼痛', '，', '当时', '至', '梅州市', '人民', '医院', '就诊', '，', '胸部', 'CT', '提示', '：', '“', '右侧', '血气胸', '、', '右肺', '挫伤', '、', '右侧', '肩胛骨', '骨折', '、', '右侧', '锁骨', '骨折', '、', '右侧', '多发', '肋骨', '骨折', '”', '，', '入院', '后', '行', '“', '右侧', '第', '4', '、', '5', '、', '6', '肋骨', '骨折', '切开', '复位', '固定术', '”', '并予', '抗炎', '、', '止血', '、', '化痰', '处理', '后', '症状', '好转', '出院', '，', '后', '患者', '感右胸', '隐痛', '伴', '胸闷', '，', '平躺', '时', '明显', '，', '无', '头晕', '、', '头痛', '，', '无', '发热', '、', '畏寒', '，', '为求', '进一步', '诊治', '患者', '入', '我院', '治疗', '。', '患者', '起病', '以来', '，', '精神', '、', '胃纳', '、', '睡眠', '可', '，', '大小便', '如常', '，', '体重', '未', '见', '明显', '改变', '。'], ['患者', '于', '5', '年前', '，', '出现', '咳嗽', '、', '咳痰', '，', '多于', '早上', '起床', '时', '，', '伴有', '流涕', '为', '清涕', '，', '无', '明显', '鼻塞', '， ...

# %%
df_patient_disease_record_extracted['desease_describe_words'] = np.nan
df_patient_disease_record_extracted.head()
# Out:
#        INPATIENT_NO                                          NODEVALUE  \
# 275  ZY010000365305  患者1周前无明显诱因开始出现发热，最高体温37.9℃，无伴畏寒、寒战、皮疹，无明显时间规律，...
# 315  ZY060000321757  患者2010-11因咳嗽咳痰就诊于当地医院，行胸部CT提示1、考虑双肺矽肺并双侧局部胸膜增厚...
# 347  ZY110000280478  患者7年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...
# 416  ZY010000365630  患者2月余前外伤致右胸疼痛伴全身多处疼痛，当时至梅州市人民医院就诊，胸部CT提示：“右侧血气...
# 512  ZY010000365806  患者于5年前，出现咳嗽、咳痰，多于早上起床时，伴有流涕为清涕，无明显鼻塞，无流脓鼻涕。并且出...
#
#      desease_describe_words
# 275                     NaN
# 315                     NaN
# 347                     NaN
# 416                     NaN
# 512                     NaN

# %%
df_patient_disease_record_extracted['desease_describe_words'] = words_record_list
df_patient_disease_record_extracted.head()
# Out:
#        INPATIENT_NO                                          NODEVALUE  \
# 275  ZY010000365305  患者1周前无明显诱因开始出现发热，最高体温37.9℃，无伴畏寒、寒战、皮疹，无明显时间规律，...
# 315  ZY060000321757  患者2010-11因咳嗽咳痰就诊于当地医院，行胸部CT提示1、考虑双肺矽肺并双侧局部胸膜增厚...
# 347  ZY110000280478  患者7年前无明显诱因出现咳嗽、咳痰，为阵发性咳，咳声高亢，少量白泡沫痰，尚可咯出，伴气促，以...
# 416  ZY010000365630  患者2月余前外伤致右胸疼痛伴全身多处疼痛，当时至梅州市人民医院就诊，胸部CT提示：“右侧血气...
# 512  ZY010000365806  患者于5年前，出现咳嗽、咳痰，多于早上起床时，伴有流涕为清涕，无明显鼻塞，无流脓鼻涕。并且出...
#
#                                 desease_describe_words
# 275  [患者, 1, 周前, 无, 明显, 诱因, 开始, 出现, 发热, ，, 最高, 体温, ...
# 315  [患者, 2010, -, 11, 因, 咳嗽, 咳痰, 就诊, 于, 当地, 医院, ，,...
# 347  [患者, 7, 年前, 无, 明显, 诱因, 出现, 咳嗽, 、, 咳痰, ，, 为, 阵发...
# 416  [患者, 2, 月余, 前, 外伤, 致, 右, 胸, 疼痛, 伴, 全身, 多处, 疼痛,...
# 512  [患者, 于, 5, 年前, ，, 出现, 咳嗽, 、, 咳痰, ，, 多于, 早上, 起床...

# %%
vocab = set()
for each in words_record_list:
    for word in each:
        vocab.add(word)

print(len(vocab))
print(vocab)
# Out:
# 6764
# {'无黑', '1.', '肿大', '书面报告', '软', '减慢', 'S7', '东莞', '剧烈', '偏少', 'min', '前于', '孔型', '影同', '气管', '可以', '.56', '问题', '浓度', '减轻', '溴铵', '普乐', '肢体', 'KUB5375mg', '云浮市', '时断时续', '821', '驱蚊剂', '酸钠', '心累', '脑桥', '左右侧', '.6', 'p63', '扭', '喷雾剂', '21.61', '环丙沙星', '查有', '百', '0.035', '普宁', '重新', '无喘鸣', '改善', 'PTCD', '肉眼', '抽液', '稳', '播散', '放血', '皮肤病', '气泡', '最初', '油烟', 'Ventolin', '基底', '血', '咪唑', '美罗培南', '去年', '病情', '静止', '输', '逆转', '.32', '2012', '美曲塞', '通', '颈椎病', '影像', '黄青', '只能', '单胞菌', '原因', '个', '伪影', '旁型', '无汗', '保心', '单位', '经查', '额部', '培养', '受体', '难以', 'WBC9', '半球', 'ROS1', '松针', '544', '～', '于闻', '加剧', '回家', '无明', '纤维化', '排斥', '于仙', '胸段', '眩晕', '小瓶', '钠尿肽', '主要', '骨质增生', '柳州', '极少量', '新泰', '昨晚', '粒', 'mg', '快步', '喷洒', '明显降低', '肠管', '补金片', '求返', '淋巴', '39.6', '煤烟', '颅内', '追踪', '体检', '中医', '华干', '彩超', '痛感', '斤', '尿急', '词', '予以', '北京大学', '动能', '临床', 'OSAHS', '压迫', '簇', '黑亮', '晚', '支持', '阿司', '后遗症', '诉感', '摄氏度', '于', '4.', '尖区', '18.82', '返院', '禅城', '3.36', '动辄', '窦性', '结缔组织', '诺', '透亮', '矽肺', '购买', '示无', '罗氟司', '嘶哑', '求诊', '百分数', '赤', '拟局', '彩', '丙球', 'proBNP', '最大', '38', '0.37', '覆盖', '上腔', '化酶', '灰黄', '甙', '96', '纪念', '对阵', '周', '肺不张', '无关', '泡沫痰', '直径', '核固缩', '陆河县', '触及', '牛磺丸', '汕头', '左克', '那他', '正常', '大炮', '第三', '纹理', '胸科', '肺段性', '我', '包块', '一层楼', '小许', '15.02', '诉近', '性疾病', '多发', '逐步', 'qn', '逐至', '口干', '半流质', 'TSH', '存在', '美卓乐', '遗忘', '缓释片', '粉红色', '陈旧性', '康复', '潮州', '太罗后', '胸椎', '反应', '无足', '分别', 'TP45', '24', '暂时', '磷状', '自主', '突起', '同等', '升高', '需取', '头孢菌素', '要求', '予护', '肋骨', '喜', '初未', '80.3', '解黑', '改变', '快速', '奥达', '执行', 'PCT', '管后', '喷射', '季肋', '甲状腺肿', '阿斯', 'gD1', '某', '早', '并较', '诱发', '有时', '34', '吸', '行下', '心律失常', '胺', '无喘促', '癌栓', '一月', '距离', '腓', '呼之', '苔癣', '予收', '前在', 'FEV1', '莫德', 'NapsinA', '相连', '间歇性', '急诊科', '822', '始来', '酸软', '置入', '洗液', '边界', '后多在', '8.6', '我院', '主动脉弓', '平时', '二十余口', '48.1', '未有', '254.4', '瘫痪', '经皮', '鼾症', '西沙', '多巴胺', '黄疸', '胃癌', '逐年', '标本', '38.3', '皮下', '透', 'CA724', '腰椎病', '神经纤维', '并见', '思力', '吸除', '血清', '滴丸', '有眼干', '年期', '体', '送到', '织炎', '预计', 'L4', '维酸钾', '天来', '限制性', '声', 'Nut', '不能', '尿毒', '衰竭', '随眠', '同前', '星片', '三层楼', '螺旋杆菌', '在外', '半胱氨酸', '利福喷', 'q8h', '祛痰', '粉', '结片', '心肌梗塞', '可退', '可必信', '地', '面色苍白', '普宁市', '少', '下见', '睾丸', '泰能', ']', '吸烟史', '签字', '干酪', '另', '霍奇金', 'FEV59', '实验室', '胆囊结石', '皲裂', '轻度', '肛', '相关性', '新克君', '67', '看', '室行', '灵', 'D8', '阿托', '含', '之间', '影查', '清晨', '稍动', '乳头状', '全', 'Villin', '罗湖', '心影略', '机械', '.7', '风湿', '即', '拍', '扩管', '管腔', '2017.12.27', '心律', '溢出', '软骨', '影像学', '中山医科大学', '饮水', '止晕', 'CX3', '块', '药沙', '机化', '绝对', '哈气', '黄脓涕', '中成药', 'TNM', '嗅', '呋辛', 'BLVR', '照亮', '初始', '数天', '阻滞', '次数', '双侧', '红色', '行胸', '便血', '附属', '肺下', '前少', '粉尘', '上半身', 'ISOTONIX', '癌细胞', '一日', '中', '患病', '89.3', 'HRZE', '颜色', '破溃', '转暖', '7.418', '相', '变形', '稀疏', 'Q3W', '后效', '多余', '方面', '假瘤', 'COPD', 'MC', '巢', '滴鼻', '沙丁胺醇', '12.7', '四联', '呕', '拔除', '相应', '6', '降钙素', 'X', '眼科', 'EBER', '剑', '求治', 'PPD', '仅', '嗳气', 'CCP', '左心', '难忍', '干眼', '美特', '前前', '中段', '中大', '就诊', '左偏', '分院', '趋势', '重组', '洸', '红', '广州', '压迫感', '腰酸', '黄白', '顶叶', 'N', '脂肪组织', '体征', '煎熬', '×', '急救车', '吃', '紊乱', 'g', '人们', '博罗县', '致密', '肺间', '坚持', '其中', '野', '缓步', '无咽痒咽痛', '培南', '肺心病', '分压', '将', '均匀', '31', '疲乏', '代述', '电子鼻', '12.69', '平均', '枕叶', '类癌', '信丰县', '可比', '与外', '变扁', 'D', '52', '米乐松', '血象', '陪同', '坠', '从事', '复', '29.5', '喷雾', '癫痫', '频率', '限期', '’', '反射', '病原学', '畸形', '揭阳市', '予改', '净', '咳中', '环状', '过性', '曾经', '苍白', 'L1', '铁血', '措施', '123', '浮肿', '化生', '解', '甘草片', '段散', '兴宁市', '样感', '转移性', '考虑', '未见好转', '诱发电位', '复查', '模特', '垠', '多见于', '天晴', '前有', '先予', '.4', '运动量', '234', '缘于', '行全', '下段', '无院', '二甲', '休克', '肝细胞', '予抑', '着', '西', '需与', '镜示', '增生症', '分型', '游走', '软便', '过敏', '龙岩市', '通畅', '降低', '综合征', '无二', '适可', '予行', '粉红', '肺尖', '座位', '8.8', '不畅', '传染病', '精神紧张', '.37', '新增', '烧灼感', '多月', '提', '酸疼', '多汗', '心房扑动', '转', '环', '仙', '2017.7.10', '组胺', '比索', '金双歧', '39.7', '神经性', '术口', '序', '干燥', '诊于', '畅后', '伴酸胀感', '残端', '胆囊', '膝关节', '量', '入睡', 'CK5', '介入', '连身', '神经内科', '随着', '白黄稠', '全院', '征', '达生', ' ...

# %% [markdown]
# # 2）word embedding

# %%
vocab_size = len(vocab)
word_to_ix = { word: i for i, word in enumerate(vocab) }
ix_to_word = { i: word for i, word in enumerate(vocab) }
print(ix_to_word)
# Out:
# {0: '无黑', 1: '1.', 2: '肿大', 3: '书面报告', 4: '软', 5: '减慢', 6: 'S7', 7: '东莞', 8: '剧烈', 9: '偏少', 10: 'min', 11: '前于', 12: '孔型', 13: '影同', 14: '气管', 15: '可以', 16: '.56', 17: '问题', 18: '浓度', 19: '减轻', 20: '溴铵', 21: '普乐', 22: '肢体', 23: 'KUB5375mg', 24: '云浮市', 25: '时断时续', 26: '821', 27: '驱蚊剂', 28: '酸钠', 29: '心累', 30: '脑桥', 31: '左右侧', 32: '.6', 33: 'p63', 34: '扭', 35: '喷雾剂', 36: '21.61', 37: '环丙沙星', 38: '查有', 39: '百', 40: '0.035', 41: '普宁', 42: '重新', 43: '无喘鸣', 44: '改善', 45: 'PTCD', 46: '肉眼', 47: '抽液', 48: '稳', 49: '播散', 50: '放血', 51: '皮肤病', 52: '气泡', 53: '最初', 54: '油烟', 55: 'Ventolin', 56: '基底', 57: '血', 58: '咪唑', 59: '美罗培南', 60: '去年', 61: '病情', 62: '静止', 63: '输', 64: '逆转', 65: '.32', 66: '2012', 67: '美曲塞', 68: '通', 69: '颈椎病', 70: '影像', 71: '黄青', 72: '只能', 73: '单胞菌', 74: '原因', 75: '个', 76: '伪影', 77: '旁型', 78: '无汗', 79: '保心', 80: '单位', 81: '经查', 82: '额部', 83: '培养', 84: '受体', 85: '难以', 86: 'WBC9', 87: '半球', 88: 'ROS1', 89: '松针', 90: '544', 91: '～', 92: '于闻', 93: '加剧', 94: '回家', 95: '无明', 96: '纤维化', 97: '排斥', 98: '于仙', 99: '胸段', 100: '眩晕', 101: '小瓶', 102: '钠尿肽', 103: '主要', 104: '骨质增生', 105: '柳州', 106: '极少量', 107: '新泰', 108: '昨晚', 109: '粒', 110: 'mg', 111: '快步', 112: '喷洒', 113: '明显降低', 114: '肠管', 115: '补金片', 116: '求返', 117: '淋巴', 118: '39.6', 119: '煤烟', 120: '颅内', 121: '追踪', 122: '体检', 123: '中医', 124: '华干', 125: '彩超', 126: '痛感', 127: '斤', 128: '尿急', 129: '词', 130: '予以', 131: '北京大学', 132: '动能', 133: '临床', 134: 'OSAHS', 135: '压迫', 136: '簇', 137: '黑亮', 138: '晚', 139: '支持', 140: '阿司', 141: '后遗症', 142: '诉感', 143: '摄氏度', 144: '于', 145: '4.', 146: '尖区', 147: '18.82', 148: '返院', 149: '禅城', 150: '3.36', 151: '动辄', 152: '窦性', 153: '结缔组织', 154: '诺', 155: '透亮', 156: '矽肺', 157: '购买', 158: '示无', 159: '罗氟司', 160: '嘶哑', 161: '求诊', 162: '百分数', 163: '赤', 164: '拟局', 165: '彩', 166: '丙球', 167: 'proBNP', 168: '最大', 169: '38', 170: '0.37', 171: '覆盖', 172: '上腔', 173: '化酶', 174: '灰黄', 175: '甙', 176: '96', 177: '纪念', 178: '对阵', 179: '周', 180: '肺不张', 181: '无关', 182: '泡沫痰', 183: '直径', 184: '核固缩', 185: '陆河县', 186: '触及', 187: '牛磺丸', 188: '汕头', 189: '左克', 190: '那他', 191: '正常', 192: '大炮', 193: '第三', 194: '纹理', 195: '胸科', 196: '肺段性', 197: '我', 198: '包块', 199: '一层楼', 200: '小许', 201: '15.02', 202: '诉近', 203: '性疾病', 204: '多发', 205: '逐步', 206: 'qn', 207: '逐至', 208: '口干', 209: '半流质', 210: 'TSH', 211: '存在', 212: '美卓乐', 213: '遗忘', 214: '缓释片', 215: '粉红色', 216: '陈旧性', 217: '康复', 218: '潮州', 219: '太罗后', 220: '胸椎', 221: '反应', 222: '无足', 223: '分别', 224: 'TP45', 225: '24', 226: '暂时', 227: '磷状', 228: '自主', 229: '突起', 230: '同等', 231: '升高', 232: '需取', 233: '头孢菌素', 234: '要求', 235: '予护', 236: '肋骨', 237: '喜', 238: '初未', 239: '80.3', 240: '解黑', 241: '改变', 242: '快速', 243: '奥达', 244: '执行', 245: 'PCT', 246: '管后', 247: '喷射', 248: '季肋', 249: '甲状腺肿', 250: '阿斯', 251: 'gD1', 252: '某', 253: '早', 254: '并较', 255: '诱发', 256: '有时', 257: '34', 258: '吸', 259: '行下', 260: '心律失常', 261: '胺', 262: '无喘促', 263: '癌栓', 264: '一月', 265: '距离', 266: '腓', 267: '呼之', 268: '苔癣', 269: '予收', 270: '前在', 271: 'FEV1', 272: '莫德', 273: 'NapsinA', 274: '相连', 275: '间歇性', 276: '急诊科', 277: '822', 278: '始来', 279: '酸软', 280: '置入', 281: '洗液', 282: '边界', 283: '后多在', 284: '8.6', 285: '我院', 286: '主动脉弓', 287: '平时', 288: '二十余口', 289: '48.1', 290: '未有', 291: '254.4', 292: '瘫痪', 293: '经皮', 294: '鼾症', 295: '西沙', 296: '多巴胺', 297: '黄疸', 298: '胃癌', 299: '逐年', 300: '标本', 301: '38.3', 302: '皮下', 303: '透', 304: 'CA724', 305: '腰椎病', 306: '神经纤维', 307: '并见', 308: '思力', 309: '吸除', 310: '血清', 311: '滴丸', 312: '有眼干', 313: '年期', 314: '体', 315: '送到', 316: '织炎', 317: '预计', 318: 'L4', 319: '维酸钾', 320: '天来', 321: '限制性', 322: '声', 323: 'Nut', 324: '不能', 325: '尿毒', 326: '衰竭', 327: '随眠', 328: '同前', 329: '星片', 330: '三层楼', 331: '螺旋杆菌', 332: '在外', 333: '半胱氨酸', 334: '利福喷', 335: 'q8h', 336: '祛痰', 337: '粉', 338: '结片', 339: '心肌梗塞', 340: '可退', 341: '可必信', 342: '地', 343: '面色苍白', 344: '普宁市', 345: '少', 346: '下见', 347: '睾丸', 348: '泰能', 349: ']', 350: '吸烟史', 351: '签字', 352: '干酪', 353: '另', 354: '霍奇金', 355: 'FEV59', 356: '实验室', 357: '胆囊结石', 358: '皲裂', 359: '轻度', 360: '肛', 361: ' ...

# %%
data = []

for  ii in range(len(words_record_list)):
    words = words_record_list[ii]    
    for i in range(2, len(words) - 2):
        context = [ words[i-2], words[i-1], words[i+1], words[i+2] ]
        target = words[i]        
        data.append((context, target))
        
print(data[:5])
# Out:
# [(['患者', '1', '无', '明显'], '周前'), (['1', '周前', '明显', '诱因'], '无'), (['周前', '无', '诱因', '开始'], '明显'), (['无', '明显', '开始', '出现'], '诱因'), (['明显', '诱因', '出现', '发热'], '开始')]

# %%
# 为了训练把数据改成如下形式
# data_t = []
# for  ii in range(len(words_record_list)):
#     words = words_record_list[ii]
#     for i in range(2, len(words) - 2):
#         target = [ words[i-2], words[i-1], words[i+1], words[i+2] ]
#         context = words[i]
#         for iii in range(len(target)):
#             data_t.append( (context, target[iii]))

        
# print(data_t[:20])

# data
# [('周前', ['患者', '1', '无', '明显']), ('无', ['1', '周前', '明显', '诱因']), ('明显', ['周前', '无', '诱因', '开始']), ('诱因', ['无', '明显', '开始', '出现']), ('开始', ['明显', '诱因', '出现', '发热'])]
# data_t
# [('周前', '患者'), ('周前', '1'), ('周前', '无'), ('周前', '明显'), ('无', '1'), ('无', '周前'), ('无', '明显'), ('无', '诱因'), ('明显', '周前'), ('明显', '无'), ('明显', '诱因'), ('明显', '开始'), ('诱因', '无'), ('诱因', '明显'), ('诱因', '开始'), ('诱因', '出现'), ('开始', '明显'), ('开始', '诱因'), ('开始', '出现'), ('开始', '发热')]
# Out:
# [('周前', '患者'), ('周前', '1'), ('周前', '无'), ('周前', '明显'), ('无', '1'), ('无', '周前'), ('无', '明显'), ('无', '诱因'), ('明显', '周前'), ('明显', '无'), ('明显', '诱因'), ('明显', '开始'), ('诱因', '无'), ('诱因', '明显'), ('诱因', '开始'), ('诱因', '出现'), ('开始', '明显'), ('开始', '诱因'), ('开始', '出现'), ('开始', '发热')]

# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# 上下文宽度 用data_t为1，因为已经处理成如上的（数据，标签）对,用data训练则为4
CONTEXT_SIZE = 2  # 2 words to the left, 2 to the right

# embedding 维度
EMBEDDING_DIM = 64

# CBOW Model.
class CBOW(nn.Module):
    def __init__(self, vocab_size, embedding_dim, context_size):
        super(CBOW,self).__init__() 
        self.embeddings = nn.Embedding(vocab_size, embedding_dim) # embeddings， 待训练参数为embedding词表
        self.linear1 = nn.Linear(embedding_dim, vocab_size) # 待训练参数为 A b
#         self.linear1 = nn.Linear(context_size * embedding_dim, 128)
#         self.linear2 = nn.Linear(128, vocab_size)
 
 
    def forward(self, inputs):
        embeds = self.embeddings(inputs)
        add_embeds = torch.sum(embeds, dim=0).view(1,-1) # 相加后reshape
        out = self.linear1(add_embeds)
        log_probs = F.log_softmax(out)
        return log_probs
#         embeds = self.embeddings(inputs).view((1, -1))
#         out = F.relu(self.linear1(embeds))
#         out = self.linear2(out)
#         log_probs = F.log_softmax(out, dim=1)
#         return log_probs

# %%
# create your model and train.  here are some functions to help you make
# the data ready for use by your module
 
def make_context_vector(context, word_to_ix):
    idxs = [word_to_ix[w] for w in context]
    tensor = torch.LongTensor(idxs)
    return Variable(tensor)
 
make_context_vector(data[0][0], word_to_ix)  # example
# Out:
# tensor([4415, 3259, 4269, 1752])

# %%
# 选择损失函数, 优化方法, 实例化网络
# 声明loss model optimizer
losses = []
loss_function = nn.NLLLoss()
model = CBOW(vocab_size, embedding_dim=EMBEDDING_DIM, context_size=CONTEXT_SIZE)
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %%
from tqdm import tqdm

# 对于每一个epoch
for epoch in tqdm(range(10)):
    total_loss = torch.FloatTensor([0])
    i = 0
    for context, target in data:
        i += 1
        context_idxs = [word_to_ix[w] for w in context]
        target_idx = word_to_ix[target]
        context_var = Variable(torch.LongTensor(context_idxs))
        target_var = Variable(torch.LongTensor([target_idx]))
    
        # 清空梯度缓存
        model.zero_grad()
    
        # 计算前向过程
        log_probs = model(context_var)
    
        #  计算损失
#         loss = loss_function(log_probs, torch.autograd.Variable(torch.LongTensor([word_to_ix[target]])))
        loss = loss_function(log_probs,target_var)
    
        #  反向传播, 优化一步
        loss.backward()
        optimizer.step()
    
        total_loss += loss.data
        
        if (i+1)%10000 == 0:
            print( "epoch {}/10, iteration {}/{}, loss: {}".format(epoch+1, i+1, len(data), loss.data) )
            
    losses.append(total_loss)
    
# 打印一下损失
print(losses) 

# 保存和加载整个模型
torch.save(model, 'lstm_autoencoder_patient_representation_model.pkl')
model = torch.load('lstm_autoencoder_patient_representation_model.pkl')
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]D:\program\Anaconda\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# epoch 1/10, iteration 10000/1309220, loss: 8.510682106018066
# epoch 1/10, iteration 20000/1309220, loss: 3.4632949829101562
# epoch 1/10, iteration 30000/1309220, loss: 7.6747026443481445
# epoch 1/10, iteration 40000/1309220, loss: 7.565309047698975
# epoch 1/10, iteration 50000/1309220, loss: 2.7333455085754395
# epoch 1/10, iteration 60000/1309220, loss: 9.99576187133789
# epoch 1/10, iteration 70000/1309220, loss: 9.7677001953125
# epoch 1/10, iteration 80000/1309220, loss: 4.753539562225342
# epoch 1/10, iteration 90000/1309220, loss: 9.307669639587402
# epoch 1/10, iteration 100000/1309220, loss: 1.963268756866455
# epoch 1/10, iteration 110000/1309220, loss: 5.691528797149658
# epoch 1/10, iteration 120000/1309220, loss: 2.225729465484619
# epoch 1/10, iteration 130000/1309220, loss: 1.2245874404907227
# epoch 1/10, iteration 140000/1309220, loss: 10.44206428527832
# epoch 1/10, iteration 150000/1309220, loss: 4.871461391448975
# epoch 1/10, iteration 160000/1309220, loss: 1.0805950164794922
# epoch 1/10, iteration 170000/1309220, loss: 0.42125415802001953
# epoch 1/10, iteration 180000/1309220, loss: 12.450176239013672
# epoch 1/10, iteration 190000/1309220, loss: 4.296199321746826
# epoch 1/10, iteration 200000/1309220, loss: 0.8778924942016602
# epoch 1/10, iteration 210000/1309220, loss: 6.322772026062012
# epoch 1/10, iteration 220000/1309220, loss: 3.30281925201416
# epoch 1/10, iteration 230000/1309220, loss: 8.726157188415527
# epoch 1/10, iteration 240000/1309220, loss: 10.742838859558105
# epoch 1/10, iteration 250000/1309220, loss: 2.6688528060913086
# epoch 1/10, iteration 260000/1309220, loss: 0.8466463088989258
# epoch 1/10, iteration 270000/1309220, loss: 1.108224868774414
# epoch 1/10, iteration 280000/1309220, loss: 2.8402748107910156
# epoch 1/10, iteration 290000/1309220, loss: 1.2169475555419922
# epoch 1/10, iteration 300000/1309220, loss: 6.236843109130859
# epoch 1/10, iteration 310000/1309220, loss: 3.5119810104370117
# epoch 1/10, iteration 320000/1309220, loss: 0.6468429565429688
#  10%|███████▉                                                                       | 1/10 [23:42<3:33:24, 1422.68s/it]
# epoch 2/10, iteration 10000/1309220, loss: 0.5267562866210938
# epoch 2/10, iteration 20000/1309220, loss: 1.8451642990112305
# epoch 2/10, iteration 30000/1309220, loss: 1.6862983703613281
# epoch 2/10, iteration 40000/1309220, loss: 6.601011276245117
# epoch 2/10, iteration 50000/1309220, loss: 1.273946762084961
# epoch 2/10, iteration 60000/1309220, loss: 8.327686309814453
# epoch 2/10, iteration 70000/1309220, loss: 8.614442825317383
# epoch 2/10, iteration 80000/1309220, loss: 2.414125442504883
# epoch 2/10, iteration 90000/1309220, loss: 7.031552791595459
# epoch 2/10, iteration 100000/1309220, loss: 1.3387441635131836
# epoch 2/10, iteration 110000/1309220, loss: 2.504683494567871
# epoch 2/10, iteration 120000/1309220, loss: 0.8918867111206055
# epoch 2/10, iteration 130000/1309220, loss: 1.3893842697143555
# epoch 2/10, iteration 140000/1309220, loss: 8.722773551940918
# epoch 2/10, iteration 150000/1309220, loss: 4.640092372894287
# epoch 2/10, iteration 160000/1309220, loss: 0.8479270935058594
# epoch 2/10, iteration 170000/1309220, loss: 0.31696605682373047
# epoch 2/10, iteration 180000/1309220, loss: 10.360666275024414
# epoch 2/10, iteration 190000/1309220, loss: 4.14949893951416
# epoch 2/10, iteration 200000/1309220, loss: 0.8112430572509766
# epoch 2/10, iteration 210000/1309220, loss: 6.54720401763916
# epoch 2/10, iteration 220000/1309220, loss: 2.851813793182373
# epoch 2/10, iteration 230000/1309220, loss: 9.109477996826172
# epoch 2/10, iteration 240000/1309220, loss: 11.044857025146484
# epoch 2/10, iteration 250000/1309220, loss: 2.923569679260254
# epoch 2/10, iteration 260000/1309220, loss: 0.7555313110351562
# epoch 2/10, iteration 270000/1309220, loss: 0.8201322555541992
# epoch 2/10, iteration 280000/1309220, loss: 2.863920211791992
# epoch 2/10, iteration 290000/1309220, loss: 0.976104736328125
# epoch 2/10, iteration 300000/1309220, loss: 6.526857376098633
# epoch 2/10, iteration 310000/1309220, loss: 3.5215063095092773
# epoch 2/10, iteration 320000/1309220, loss: 0.5729007720947266
#  20%|███████████████▊                                                               | 2/10 [46:23<3:07:13, 1404.19s/it]
# epoch 3/10, iteration 10000/1309220, loss: 0.3751201629638672
# epoch 3/10, iteration 20000/1309220, loss: 1.7537298202514648
# epoch 3/10, iteration 30000/1309220, loss: 1.5064382553100586
# epoch 3/10, iteration 40000/1309220, loss: 6.642228126525879
# epoch 3/10, iteration 50000/1309220, loss: 1.2049322128295898
# epoch 3/10, iteration 60000/1309220, loss: 7.615816593170166
# epoch 3/10, iteration 70000/1309220, loss: 7.447352409362793
# epoch 3/10, iteration 80000/1309220, loss: 2.1507482528686523
# epoch 3/10, iteration 90000/1309220, loss: 5.199439525604248
# epoch 3/10, iteration 100000/1309220, loss: 1.0899391174316406
# epoch 3/10, iteration 110000/1309220, loss: 2.558216094970703
# epoch 3/10, iteration 120000/1309220, loss: 0.7534809112548828
# epoch 3/10, iteration 130000/1309220, loss: 1.1986589431762695
# epoch 3/10, iteration 140000/1309220, loss: 7.205329418182373
# epoch 3/10, iteration 150000/1309220, loss: 4.57346773147583
# epoch 3/10, iteration 160000/1309220, loss: 0.7264928817749023
# epoch 3/10, iteration 170000/1309220, loss: 0.2873706817626953
# epoch 3/10, iteration 180000/1309220, loss: 9.347466468811035
# epoch 3/10, iteration 190000/1309220, loss: 4.226788520812988
# epoch 3/10, iteration 200000/1309220, loss: 0.7447385787963867
# epoch 3/10, iteration 210000/1309220, loss: 6.584912300109863
# epoch 3/10, iteration 220000/1309220, loss: 2.7807130813598633
# epoch 3/10, iteration 230000/1309220, loss: 9.431733131408691
# epoch 3/10, iteration 240000/1309220, loss: 11.09715461730957
# epoch 3/10, iteration 250000/1309220, loss: 2.9754323959350586
# epoch 3/10, iteration 260000/1309220, loss: 0.7483463287353516
# epoch 3/10, iteration 270000/1309220, loss: 0.713043212890625
# epoch 3/10, iteration 280000/1309220, loss: 2.8964366912841797
# epoch 3/10, iteration 290000/1309220, loss: 0.8865060806274414
# epoch 3/10, iteration 300000/1309220, loss: 6.592674255371094
# epoch 3/10, iteration 310000/1309220, loss: 3.543468475341797
# epoch 3/10, iteration 320000/1309220, loss: 0.5469512939453125
#  30%|███████████████████████                                                      | 3/10 [1:08:06<2:40:17, 1373.87s/it]
# epoch 4/10, iteration 10000/1309220, loss: 0.32906055450439453
# epoch 4/10, iteration 20000/1309220, loss: 1.7145309448242188
# epoch 4/10, iteration 30000/1309220, loss: 1.4113683700561523
# epoch 4/10, iteration 40000/1309220, loss: 6.776236057281494
# epoch 4/10, iteration 50000/1309220, loss: 1.1827878952026367
# epoch 4/10, iteration 60000/1309220, loss: 7.32417106628418
# epoch 4/10, iteration 70000/1309220, loss: 6.221864223480225
# epoch 4/10, iteration 80000/1309220, loss: 2.076284408569336
# epoch 4/10, iteration 90000/1309220, loss: 4.259149074554443
# epoch 4/10, iteration 100000/1309220, loss: 0.9182004928588867
# epoch 4/10, iteration 110000/1309220, loss: 2.4251937866210938
# epoch 4/10, iteration 120000/1309220, loss: 0.6867046356201172
# epoch 4/10, iteration 130000/1309220, loss: 1.1020803451538086
# epoch 4/10, iteration 140000/1309220, loss: 6.110570430755615
# epoch 4/10, iteration 150000/1309220, loss: 4.501145362854004
# epoch 4/10, iteration 160000/1309220, loss: 0.6204843521118164
# epoch 4/10, iteration 170000/1309220, loss: 0.2764139175415039
# epoch 4/10, iteration 180000/1309220, loss: 9.444265365600586
# epoch 4/10, iteration 190000/1309220, loss: 4.367581844329834
# epoch 4/10, iteration 200000/1309220, loss: 0.6959095001220703
# epoch 4/10, iteration 210000/1309220, loss: 6.552122592926025
# epoch 4/10, iteration 220000/1309220, loss: 2.7158660888671875
# epoch 4/10, iteration 230000/1309220, loss: 9.447576522827148
# epoch 4/10, iteration 240000/1309220, loss: 11.1458740234375
# epoch 4/10, iteration 250000/1309220, loss: 3.0010032653808594
# epoch 4/10, iteration 260000/1309220, loss: 0.7245302200317383
# epoch 4/10, iteration 270000/1309220, loss: 0.6543769836425781
# epoch 4/10, iteration 280000/1309220, loss: 2.8918161392211914
# epoch 4/10, iteration 290000/1309220, loss: 0.8329753875732422
# epoch 4/10, iteration 300000/1309220, loss: 6.556831359863281
# epoch 4/10, iteration 310000/1309220, loss: 3.5722742080688477
# epoch 4/10, iteration 320000/1309220, loss: 0.5288677215576172
#  40%|██████████████████████████████▊                                              | 4/10 [1:30:55<2:17:13, 1372.30s/it]
# epoch 5/10, iteration 10000/1309220, loss: 0.3023843765258789
# epoch 5/10, iteration 20000/1309220, loss: 1.6985979080200195
# epoch 5/10, iteration 30000/1309220, loss: 1.341008186340332
# epoch 5/10, iteration 40000/1309220, loss: 6.9091033935546875
# epoch 5/10, iteration 50000/1309220, loss: 1.168013572692871
# epoch 5/10, iteration 60000/1309220, loss: 7.170835494995117
# epoch 5/10, iteration 70000/1309220, loss: 5.083639144897461
# epoch 5/10, iteration 80000/1309220, loss: 2.047792434692383
# epoch 5/10, iteration 90000/1309220, loss: 3.7150774002075195
# epoch 5/10, iteration 100000/1309220, loss: 0.8088665008544922
# epoch 5/10, iteration 110000/1309220, loss: 2.2694644927978516
# epoch 5/10, iteration 120000/1309220, loss: 0.6451444625854492
# epoch 5/10, iteration 130000/1309220, loss: 1.0443801879882812
# epoch 5/10, iteration 140000/1309220, loss: 5.3425421714782715
# epoch 5/10, iteration 150000/1309220, loss: 4.428217887878418
# epoch 5/10, iteration 160000/1309220, loss: 0.5337810516357422
# epoch 5/10, iteration 170000/1309220, loss: 0.26857948303222656
# epoch 5/10, iteration 180000/1309220, loss: 9.607088088989258
# epoch 5/10, iteration 190000/1309220, loss: 4.492391586303711
# epoch 5/10, iteration 200000/1309220, loss: 0.6580047607421875
# epoch 5/10, iteration 210000/1309220, loss: 6.4969706535339355
# epoch 5/10, iteration 220000/1309220, loss: 2.6685428619384766
# epoch 5/10, iteration 230000/1309220, loss: 9.313400268554688
# epoch 5/10, iteration 240000/1309220, loss: 11.237433433532715
# epoch 5/10, iteration 250000/1309220, loss: 3.0137510299682617
# epoch 5/10, iteration 260000/1309220, loss: 0.6944723129272461
# epoch 5/10, iteration 270000/1309220, loss: 0.6140499114990234
# epoch 5/10, iteration 280000/1309220, loss: 2.870570182800293
# epoch 5/10, iteration 290000/1309220, loss: 0.7931280136108398
# epoch 5/10, iteration 300000/1309220, loss: 6.476047515869141
# epoch 5/10, iteration 310000/1309220, loss: 3.603147506713867
# epoch 5/10, iteration 320000/1309220, loss: 0.512019157409668
#  50%|██████████████████████████████████████▌                                      | 5/10 [1:52:49<1:52:54, 1354.91s/it]
# epoch 6/10, iteration 10000/1309220, loss: 0.27809906005859375
# epoch 6/10, iteration 20000/1309220, loss: 1.6964082717895508
# epoch 6/10, iteration 30000/1309220, loss: 1.2847833633422852
# epoch 6/10, iteration 40000/1309220, loss: 7.024908065795898
# epoch 6/10, iteration 50000/1309220, loss: 1.1599254608154297
# epoch 6/10, iteration 60000/1309220, loss: 7.065859794616699
# epoch 6/10, iteration 70000/1309220, loss: 4.228691101074219
# epoch 6/10, iteration 80000/1309220, loss: 2.0330209732055664
# epoch 6/10, iteration 90000/1309220, loss: 3.302853584289551
# epoch 6/10, iteration 100000/1309220, loss: 0.7347850799560547
# epoch 6/10, iteration 110000/1309220, loss: 2.142777442932129
# epoch 6/10, iteration 120000/1309220, loss: 0.6163997650146484
# epoch 6/10, iteration 130000/1309220, loss: 1.0047292709350586
# epoch 6/10, iteration 140000/1309220, loss: 4.788650989532471
# epoch 6/10, iteration 150000/1309220, loss: 4.360335350036621
# epoch 6/10, iteration 160000/1309220, loss: 0.4677095413208008
# epoch 6/10, iteration 170000/1309220, loss: 0.2616596221923828
# epoch 6/10, iteration 180000/1309220, loss: 9.70612907409668
# epoch 6/10, iteration 190000/1309220, loss: 4.589924335479736
# epoch 6/10, iteration 200000/1309220, loss: 0.6274652481079102
# epoch 6/10, iteration 210000/1309220, loss: 6.434418678283691
# epoch 6/10, iteration 220000/1309220, loss: 2.6463327407836914
# epoch 6/10, iteration 230000/1309220, loss: 9.137462615966797
# epoch 6/10, iteration 240000/1309220, loss: 11.366747856140137
# epoch 6/10, iteration 250000/1309220, loss: 3.0065431594848633
# epoch 6/10, iteration 260000/1309220, loss: 0.6628484725952148
# epoch 6/10, iteration 270000/1309220, loss: 0.5824298858642578
# epoch 6/10, iteration 280000/1309220, loss: 2.843470573425293
# epoch 6/10, iteration 290000/1309220, loss: 0.760289192199707
# epoch 6/10, iteration 300000/1309220, loss: 6.385523319244385
# epoch 6/10, iteration 310000/1309220, loss: 3.6337404251098633
# epoch 6/10, iteration 320000/1309220, loss: 0.4973421096801758
#  60%|██████████████████████████████████████████████▏                              | 6/10 [2:15:53<1:30:54, 1363.58s/it]
# epoch 7/10, iteration 10000/1309220, loss: 0.25504016876220703
# epoch 7/10, iteration 20000/1309220, loss: 1.7038850784301758
# epoch 7/10, iteration 30000/1309220, loss: 1.2391977310180664
# epoch 7/10, iteration 40000/1309220, loss: 7.123646259307861
# epoch 7/10, iteration 50000/1309220, loss: 1.156203269958496
# epoch 7/10, iteration 60000/1309220, loss: 6.983673095703125
# epoch 7/10, iteration 70000/1309220, loss: 3.6782751083374023
# epoch 7/10, iteration 80000/1309220, loss: 2.021969795227051
# epoch 7/10, iteration 90000/1309220, loss: 2.9772205352783203
# epoch 7/10, iteration 100000/1309220, loss: 0.6806402206420898
# epoch 7/10, iteration 110000/1309220, loss: 2.0333614349365234
# epoch 7/10, iteration 120000/1309220, loss: 0.594517707824707
# epoch 7/10, iteration 130000/1309220, loss: 0.9759883880615234
# epoch 7/10, iteration 140000/1309220, loss: 4.371262073516846
# epoch 7/10, iteration 150000/1309220, loss: 4.299482345581055
# epoch 7/10, iteration 160000/1309220, loss: 0.4175996780395508
# epoch 7/10, iteration 170000/1309220, loss: 0.25600528717041016
# epoch 7/10, iteration 180000/1309220, loss: 9.761959075927734
# epoch 7/10, iteration 190000/1309220, loss: 4.662691593170166
# epoch 7/10, iteration 200000/1309220, loss: 0.6023483276367188
# epoch 7/10, iteration 210000/1309220, loss: 6.369124412536621
# epoch 7/10, iteration 220000/1309220, loss: 2.630995750427246
# epoch 7/10, iteration 230000/1309220, loss: 8.958016395568848
# epoch 7/10, iteration 240000/1309220, loss: 11.520814895629883
# epoch 7/10, iteration 250000/1309220, loss: 2.9811019897460938
# epoch 7/10, iteration 260000/1309220, loss: 0.6320333480834961
# epoch 7/10, iteration 270000/1309220, loss: 0.5555953979492188
# epoch 7/10, iteration 280000/1309220, loss: 2.814756393432617
# epoch 7/10, iteration 290000/1309220, loss: 0.7325286865234375
# epoch 7/10, iteration 300000/1309220, loss: 6.3000617027282715
# epoch 7/10, iteration 310000/1309220, loss: 3.662687301635742
# epoch 7/10, iteration 320000/1309220, loss: 0.4842853546142578
#  70%|█████████████████████████████████████████████████████▉                       | 7/10 [2:38:51<1:08:23, 1367.91s/it]
# epoch 8/10, iteration 10000/1309220, loss: 0.23385143280029297
# epoch 8/10, iteration 20000/1309220, loss: 1.7177886962890625
# epoch 8/10, iteration 30000/1309220, loss: 1.2006244659423828
# epoch 8/10, iteration 40000/1309220, loss: 7.206732749938965
# epoch 8/10, iteration 50000/1309220, loss: 1.155287742614746
# epoch 8/10, iteration 60000/1309220, loss: 6.916325569152832
# epoch 8/10, iteration 70000/1309220, loss: 3.3039894104003906
# epoch 8/10, iteration 80000/1309220, loss: 2.012542724609375
# epoch 8/10, iteration 90000/1309220, loss: 2.717172145843506
# epoch 8/10, iteration 100000/1309220, loss: 0.638336181640625
# epoch 8/10, iteration 110000/1309220, loss: 1.9316291809082031
# epoch 8/10, iteration 120000/1309220, loss: 0.5771732330322266
# epoch 8/10, iteration 130000/1309220, loss: 0.9547138214111328
# epoch 8/10, iteration 140000/1309220, loss: 4.045264720916748
# epoch 8/10, iteration 150000/1309220, loss: 4.244633674621582
# epoch 8/10, iteration 160000/1309220, loss: 0.3789215087890625
# epoch 8/10, iteration 170000/1309220, loss: 0.2515678405761719
# epoch 8/10, iteration 180000/1309220, loss: 9.791748046875
# epoch 8/10, iteration 190000/1309220, loss: 4.715425968170166
# epoch 8/10, iteration 200000/1309220, loss: 0.5813150405883789
# epoch 8/10, iteration 210000/1309220, loss: 6.30409049987793
# epoch 8/10, iteration 220000/1309220, loss: 2.6057310104370117
# epoch 8/10, iteration 230000/1309220, loss: 8.78389835357666
# epoch 8/10, iteration 240000/1309220, loss: 11.687606811523438
# epoch 8/10, iteration 250000/1309220, loss: 2.9451026916503906
# epoch 8/10, iteration 260000/1309220, loss: 0.6027412414550781
# epoch 8/10, iteration 270000/1309220, loss: 0.5318689346313477
# epoch 8/10, iteration 280000/1309220, loss: 2.786160469055176
# epoch 8/10, iteration 290000/1309220, loss: 0.7085971832275391
# epoch 8/10, iteration 300000/1309220, loss: 6.221134185791016
# epoch 8/10, iteration 310000/1309220, loss: 3.689497947692871
# epoch 8/10, iteration 320000/1309220, loss: 0.4728984832763672
#  80%|███████████████████████████████████████████████████████████████▏               | 8/10 [3:02:12<45:55, 1377.76s/it]
# epoch 9/10, iteration 10000/1309220, loss: 0.21478557586669922
# epoch 9/10, iteration 20000/1309220, loss: 1.7354507446289062
# epoch 9/10, iteration 30000/1309220, loss: 1.1664419174194336
# epoch 9/10, iteration 40000/1309220, loss: 7.275993347167969
# epoch 9/10, iteration 50000/1309220, loss: 1.1562690734863281
# epoch 9/10, iteration 60000/1309220, loss: 6.859986305236816
# epoch 9/10, iteration 70000/1309220, loss: 3.0151100158691406
# epoch 9/10, iteration 80000/1309220, loss: 2.003870964050293
# epoch 9/10, iteration 90000/1309220, loss: 2.505263328552246
# epoch 9/10, iteration 100000/1309220, loss: 0.6036462783813477
# epoch 9/10, iteration 110000/1309220, loss: 1.8374099731445312
# epoch 9/10, iteration 120000/1309220, loss: 0.5626897811889648
# epoch 9/10, iteration 130000/1309220, loss: 0.9385480880737305
# epoch 9/10, iteration 140000/1309220, loss: 3.784083843231201
# epoch 9/10, iteration 150000/1309220, loss: 4.19405460357666
# epoch 9/10, iteration 160000/1309220, loss: 0.3486804962158203
# epoch 9/10, iteration 170000/1309220, loss: 0.248260498046875
# epoch 9/10, iteration 180000/1309220, loss: 9.80455207824707
# epoch 9/10, iteration 190000/1309220, loss: 4.752433776855469
# epoch 9/10, iteration 200000/1309220, loss: 0.5634012222290039
# epoch 9/10, iteration 210000/1309220, loss: 6.240166664123535
# epoch 9/10, iteration 220000/1309220, loss: 2.5688161849975586
# epoch 9/10, iteration 230000/1309220, loss: 8.615291595458984
# epoch 9/10, iteration 240000/1309220, loss: 11.85787582397461
# epoch 9/10, iteration 250000/1309220, loss: 2.903350830078125
# epoch 9/10, iteration 260000/1309220, loss: 0.5748634338378906
# epoch 9/10, iteration 270000/1309220, loss: 0.510528564453125
# epoch 9/10, iteration 280000/1309220, loss: 2.758387565612793
# epoch 9/10, iteration 290000/1309220, loss: 0.687657356262207
# epoch 9/10, iteration 300000/1309220, loss: 6.1459832191467285
# epoch 9/10, iteration 310000/1309220, loss: 3.7138328552246094
# epoch 9/10, iteration 320000/1309220, loss: 0.4629402160644531
#  90%|███████████████████████████████████████████████████████████████████████        | 9/10 [3:24:52<22:52, 1372.39s/it]
# epoch 10/10, iteration 10000/1309220, loss: 0.19780445098876953
# epoch 10/10, iteration 20000/1309220, loss: 1.7551116943359375
# epoch 10/10, iteration 30000/1309220, loss: 1.1352577209472656
# epoch 10/10, iteration 40000/1309220, loss: 7.3340959548950195
# epoch 10/10, iteration 50000/1309220, loss: 1.158431053161621
# epoch 10/10, iteration 60000/1309220, loss: 6.812036514282227
# epoch 10/10, iteration 70000/1309220, loss: 2.7752857208251953
# epoch 10/10, iteration 80000/1309220, loss: 1.995412826538086
# epoch 10/10, iteration 90000/1309220, loss: 2.328887939453125
# epoch 10/10, iteration 100000/1309220, loss: 0.5743255615234375
# epoch 10/10, iteration 110000/1309220, loss: 1.7520465850830078
# epoch 10/10, iteration 120000/1309220, loss: 0.5498752593994141
# epoch 10/10, iteration 130000/1309220, loss: 0.9256820678710938
# epoch 10/10, iteration 140000/1309220, loss: 3.5698347091674805
# epoch 10/10, iteration 150000/1309220, loss: 4.146449565887451
# epoch 10/10, iteration 160000/1309220, loss: 0.3246307373046875
# epoch 10/10, iteration 170000/1309220, loss: 0.24607086181640625
# epoch 10/10, iteration 180000/1309220, loss: 9.80556869506836
# epoch 10/10, iteration 190000/1309220, loss: 4.776972770690918
# epoch 10/10, iteration 200000/1309220, loss: 0.547938346862793
# epoch 10/10, iteration 210000/1309220, loss: 6.177361488342285
# epoch 10/10, iteration 220000/1309220, loss: 2.5248422622680664
# epoch 10/10, iteration 230000/1309220, loss: 8.451244354248047
# epoch 10/10, iteration 240000/1309220, loss: 12.025333404541016
# epoch 10/10, iteration 250000/1309220, loss: 2.858335494995117
# epoch 10/10, iteration 260000/1309220, loss: 0.5482616424560547
# epoch 10/10, iteration 270000/1309220, loss: 0.4913063049316406
# epoch 10/10, iteration 280000/1309220, loss: 2.7318782806396484
# epoch 10/10, iteration 290000/1309220, loss: 0.6695947647094727
# epoch 10/10, iteration 300000/1309220, loss: 6.071951866149902
# epoch 10/10, iteration 310000/1309220, loss: 3.735523223876953
# epoch 10/10, iteration 320000/1309220, loss: 0.454315185546875
# 100%|██████████████████████████████████████████████████████████████████████████████| 10/10 [3:48:35<00:00, 1387.50s/it]
# [tensor([1551272.7500]), tensor([1240984.8750]), tensor([1139461.8750]), tensor([1077113.8750]), tensor([1032581.3750]), tensor([998052.1250]), tensor([969854.5625]), tensor([946071.1250]), tensor([925538.8125]), tensor([907516.4375])]

# %%
# 保存和加载整个模型
torch.save(model, 'lstm_autoencoder_patient_representation_model.pkl')
model = torch.load('lstm_autoencoder_patient_representation_model.pkl')

# 仅保存和加载模型参数(推荐使用)
torch.save(model.state_dict(), 'lstm_autoencoder_patient_representation_params.pkl')
model.load_state_dict(torch.load('lstm_autoencoder_patient_representation_params.pkl'))
# Out:
# D:\program\Anaconda\lib\site-packages\torch\serialization.py:241: UserWarning: Couldn't retrieve source code for container of type CBOW. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
word, label = data[67]
word = Variable(torch.LongTensor([word_to_ix[i] for i in word]))
out = model(word)
_, predict_label = torch.max(out, 1)
# predict_word = ix_to_word[predict_label.data[0][0]]
predict_word = ix_to_word[(predict_label.data.numpy())[0]]
print( 'real word is {}, predict word is {}'.format(label, predict_word) )
# Out:
# D:\program\Anaconda\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# real word is 尿频, predict word is 尿频

# %%
params = model.state_dict()
print(params)
# Out:
# OrderedDict([('embeddings.weight', tensor([[ 1.9352,  0.3902, -1.7150,  ...,  0.0642,  0.4895, -0.5539],
#         [-0.3255, -2.0093,  0.2971,  ..., -0.3934, -0.4072,  0.8851],
#         [-0.2236, -0.1794, -1.1018,  ..., -0.0855,  0.6822,  1.1697],
#         ...,
#         [-1.3035,  0.8503, -1.8111,  ...,  0.4319,  0.3615,  0.4141],
#         [-0.1487, -0.8110,  0.6881,  ..., -1.7945, -1.1347,  0.0368],
#         [-0.7361,  1.6724, -1.6333,  ..., -1.6531,  0.3949, -0.2154]])), ('linear1.weight', tensor([[-0.1084,  0.0110,  0.1384,  ..., -0.0353, -0.1200, -0.0253],
#         [-0.3292,  0.0855, -0.0306,  ..., -0.1952,  0.0234, -0.0964],
#         [-0.0145,  0.2629, -0.1162,  ..., -0.0346,  0.0705,  0.1431],
#         ...,
#         [ 0.3056,  0.1272, -0.0489,  ..., -0.1837,  0.0201,  0.0367],
#         [ 0.0322,  0.0804,  0.0915,  ..., -0.3735,  0.1946, -0.1004],
#         [-0.0097, -0.2213, -0.0094,  ..., -0.1101,  0.0285,  0.0894]])), ('linear1.bias', tensor([-0.1639,  0.1498, -0.1180,  ...,  0.4032, -0.1028, -0.0045]))])

# %%
print(params['embeddings.weight'])
# Out:
# tensor([[ 1.9352,  0.3902, -1.7150,  ...,  0.0642,  0.4895, -0.5539],
#         [-0.3255, -2.0093,  0.2971,  ..., -0.3934, -0.4072,  0.8851],
#         [-0.2236, -0.1794, -1.1018,  ..., -0.0855,  0.6822,  1.1697],
#         ...,
#         [-1.3035,  0.8503, -1.8111,  ...,  0.4319,  0.3615,  0.4141],
#         [-0.1487, -0.8110,  0.6881,  ..., -1.7945, -1.1347,  0.0368],
#         [-0.7361,  1.6724, -1.6333,  ..., -1.6531,  0.3949, -0.2154]])

# %% [markdown]
# # 3）病人表示模型

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
length_list = [len(x) for x in words_record_list]
MAX_LENGTH = max(length_list)
print(MAX_LENGTH)
# Out:
# 519

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math
import random


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
hidden_size = 256
# encoder1 = EncoderRNN(vocab_size, EMBEDDING_DIM).to(device)
# attn_decoder1 = AttnDecoderRNN(EMBEDDING_DIM, vocab_size, dropout_p=0.1).to(device)

encoder1 = EncoderRNN(vocab_size, EMBEDDING_DIM)
encoder1.embedding = model.embeddings
attn_decoder1 = AttnDecoderRNN(EMBEDDING_DIM, vocab_size, dropout_p=0.1)

trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-e963aaf7ba77> in <module>()
#       7 attn_decoder1 = AttnDecoderRNN(EMBEDDING_DIM, vocab_size, dropout_p=0.1)
#       8
# ----> 9 trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
#
# <ipython-input-111-29eaa6fdc28a> in trainIters(encoder, decoder, n_iters, print_every, plot_every, learning_rate)
#       8     decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
#       9     training_pairs = [tensorsFromPair(random.choice(pairs))
# ---> 10                       for i in range(n_iters)]
#      11     criterion = nn.NLLLoss()
#      12
#
# <ipython-input-111-29eaa6fdc28a> in <listcomp>(.0)
#       8     decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
#       9     training_pairs = [tensorsFromPair(random.choice(pairs))
# ---> 10                       for i in range(n_iters)]
#      11     criterion = nn.NLLLoss()
#      12
#
# NameError: name 'pairs' is not defined

# %%
# Bi-LSTM 模型 
# 实现起来很简单 只需把 nn.RNN 替换成 nn.LSTM 以及
# 添加属性 bidirectional= True
# 倍化 hidden_size
class RNN(nn.Module):
  
    def __init__(self, batch_size, num_tokens, embed_size, hidden):        
        super(RNN, self).__init__()
        
        self.batch_size = batch_size
        self.num_tokens = num_tokens
        self.embed_size = embed_size
        self.hidden = hidden
        
        self.lookup = nn.Embedding(num_tokens, embed_size)
        self.bi_LSTM = nn.LSTM(embed_size, word_gru_hidden, bidirectional= True)
        
    def forward(self, embed, state_word):
        embedded = self.lookup(embed)
        output_word, state_word = self.bi_LSTM(embedded, state_word)       
        return output_word, state_word
    
    def init_hidden(self):
        return Variable(torch.zeros(2, self.batch_size, self.hidden))

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, isCuda):
        super(EncoderRNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.isCuda = isCuda
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.relu = nn.ReLU()
        
        #initialize weights
        nn.init.xavier_uniform(self.lstm.weight_ih_l0, gain=np.sqrt(2))
        nn.init.xavier_uniform(self.lstm.weight_hh_l0, gain=np.sqrt(2))

    def forward(self, input):
        tt = torch.cuda if self.isCuda else torch
        h0 = Variable(tt.FloatTensor(self.num_layers, input.size(0), self.hidden_size))
        c0 = Variable(tt.FloatTensor(self.num_layers, input.size(0), self.hidden_size))
        encoded_input, hidden = self.lstm(input, (h0, c0))
        encoded_input = self.relu(encoded_input)
        return encoded_input

class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, num_layers, isCuda):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.isCuda = isCuda
        self.lstm = nn.LSTM(hidden_size, output_size, num_layers, batch_first=True)
        #self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
        #initialize weights
        nn.init.xavier_uniform(self.lstm.weight_ih_l0, gain=np.sqrt(2))
        nn.init.xavier_uniform(self.lstm.weight_hh_l0, gain=np.sqrt(2))
        
    def forward(self, encoded_input):
        tt = torch.cuda if self.isCuda else torch
        h0 = Variable(tt.FloatTensor(self.num_layers, encoded_input.size(0), self.output_size))
        c0 = Variable(tt.FloatTensor(self.num_layers, encoded_input.size(0), self.output_size))
        decoded_output, hidden = self.lstm(encoded_input, (h0, c0))
        decoded_output = self.sigmoid(decoded_output)
        return decoded_output

class LSTMAE(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, isCuda):
        super(LSTMAE, self).__init__()
        self.encoder = EncoderRNN(input_size, hidden_size, num_layers, isCuda)
        self.decoder = DecoderRNN(hidden_size, input_size, num_layers, isCuda)
        
    def forward(self, input):
        encoded_input = self.encoder(input)
        decoded_output = self.decoder(encoded_input)
        return decoded_output
